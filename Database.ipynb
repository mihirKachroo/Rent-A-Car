# %% [markdown]
# # Production Dataset

# %%
import pandas as pd
import numpy as np
import uuid
import random
from faker import Faker
import string
from datetime import datetime, timedelta

# %%
df = pd.read_csv("vehicles.csv")

# %%
def fill_na(column):
    actual = column.dropna().tolist()
    return column.apply(lambda x: x if pd.notna(x) else random.choice(actual))

def fill_na_vin(column):
    actual = column.dropna().tolist()
    vin_chars = string.ascii_uppercase.replace('I', '').replace('O', '').replace('Q', '') + string.digits

    def generate_random_vin():
        return ''.join(random.choices(vin_chars, k=17))
    
    return column.apply(lambda x: x if pd.notna(x) else generate_random_vin())

def generate_random_dates(n, start_date, end_date):
    start_u = start_date.value // 10**9
    end_u = end_date.value // 10**9
    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
df = df[27:]
df = df.reset_index().drop(["county", "size", "index"], axis=1)

# %%
df['drive'] = fill_na(df['drive'])
df['cylinders'] = fill_na(df['cylinders'])
df['paint_color'] = fill_na(df['paint_color'])
df['model'] = fill_na(df['model'])
df['manufacturer'] = fill_na(df['manufacturer'])
df['condition'] = fill_na(df['condition'])
df['fuel'] = fill_na(df['fuel'])
df['type'] = fill_na(df['type'])
df['VIN'] = fill_na_vin(df['VIN'])

df['cylinders'] = df['cylinders'].str.extract('(\d+)').astype(float)
df['cylinders'].fillna(df['cylinders'].dropna().sample(n=1).values[0], inplace=True)
df['cylinders'] = df['cylinders'].astype(int)


df['paint_color'] = df['paint_color'].replace('custom', 'white')
df['transmission'] = df['transmission'].replace('other', 'automatic')

df = df.rename(columns={
    "VIN": "vin"
})

end_date = pd.to_datetime('now')
start_date = end_date - pd.DateOffset(years=1)
df['posting_date'] = generate_random_dates(len(df), start_date, end_date)

df
# Out:
# C:\Users\siddh\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#                 id                                                url  \
# 0       7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2       7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3       7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4       7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426848  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426849  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426850  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426851  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426852  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# 0        auburn   https://auburn.craigslist.org  33590  2014.0          gmc
# 1        auburn   https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2        auburn   https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3        auburn   https://auburn.craigslist.org  30990  2017.0       toyota
# 4        auburn   https://auburn.craigslist.org  15000  2013.0         ford
# ...         ...                             ...    ...     ...          ...
# 426848  wyoming  https://wyoming.craigslist.org  23590  2019.0       nissan
# 426849  wyoming  https://wyoming.craigslist.org  30590  2020.0        volvo
# 426850  wyoming  https://wyoming.craigslist.org  34990  2020.0     cadillac
# 426851  wyoming  https://wyoming.craigslist.org  28990  2018.0        lexus
# 426852  wyoming  https://wyoming.craigslist.org  30590  2019.0          bmw
#
#                            model  condition  cylinders  ...  \
# 0       sierra 1500 crew cab slt       good          8  ...
# 1                 silverado 1500       good          8  ...
# 2            silverado 1500 crew       good          8  ...
# 3           tundra double cab sr       good          8  ...
# 4                      f-150 xlt  excellent          6  ...
# ...                          ...        ...        ...  ...
# 426848         maxima s sedan 4d       good          6  ...
# 426849  s60 t5 momentum sedan 4d       good          6  ...
# 426850          xt4 sport suv 4d       good          4  ...
# 426851           es 350 sedan 4d       good          6  ...
# 426852  4 series 430i gran coupe       good          4  ...
#
#                       vin  drive       type paint_color  \
# 0       3GTP1VEC4EG551563    fwd     pickup       white
# 1       1GCSCSE06AZ123805    fwd     pickup        blue
# 2       3GCPWCED5LG130317    4wd     pickup         red
# 3       5TFRM5F17HX120972    4wd     pickup         red
# 4       UZ6APLWVZM7ZN6W63    rwd      truck       black
# ...                   ...    ...        ...         ...
# 426848  1N4AA6AV6KC367801    fwd      sedan         red
# 426849  7JR102FKXLG042696    fwd      sedan         red
# 426850  1GYFZFR46LF088296    fwd  hatchback       white
# 426851  58ABK1GG4JU103853    fwd      sedan      silver
# 426852  WBA4J1C58KBM14708    rwd      coupe       white
#
#                                                 image_url  \
# 0       https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1       https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2       https://images.craigslist.org/01212_jjirIWa0y0...
# 3       https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4       https://images.craigslist.org/00404_l4loxHvdQe...
# ...                                                   ...
# 426848  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426849  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426850  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426851  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426852  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description state        lat  \
# 0       Carvana is the safer way to buy a car During t...    al  32.590000
# 1       Carvana is the safer way to buy a car During t...    al  32.590000
# 2       Carvana is the safer way to buy a car During t...    al  32.590000
# 3       Carvana is the safer way to buy a car During t...    al  32.590000
# 4       2013 F-150 XLT V6 4 Door. Good condition. Leve...    al  32.592000
# ...                                                   ...   ...        ...
# 426848  Carvana is the safer way to buy a car During t...    wy  33.786500
# 426849  Carvana is the safer way to buy a car During t...    wy  33.786500
# 426850  Carvana is the safer way to buy a car During t...    wy  33.779214
# 426851  Carvana is the safer way to buy a car During t...    wy  33.786500
# 426852  Carvana is the safer way to buy a car During t...    wy  33.779214
#
#              long        posting_date
# 0      -85.480000 2024-04-27 18:30:59
# 1      -85.480000 2024-02-28 18:59:04
# 2      -85.480000 2024-05-09 23:21:35
# 3      -85.480000 2023-11-01 02:05:15
# 4      -85.518900 2024-05-19 07:11:15
# ...           ...                 ...
# 426848 -84.445400 2023-11-09 23:35:42
# 426849 -84.445400 2023-09-17 08:04:41
# 426850 -84.411811 2023-11-18 23:26:41
# 426851 -84.445400 2024-02-01 14:48:21
# 426852 -84.411811 2023-10-26 18:57:54
#
# [426853 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'type', 'paint_color', 'image_url',
#        'description', 'state', 'lat', 'long', 'posting_date'],
#       dtype='object')

# %%
unique_cars = df[['manufacturer', 'model']].drop_duplicates().reset_index(drop=True)
unique_cars['car_id'] = range(1, len(unique_cars) + 1)

cars_table = df[["id", "manufacturer", "model", "drive", "cylinders", "transmission", "paint_color"]]

cars_table = cars_table.merge(unique_cars, on=['manufacturer', 'model'], how='left').drop_duplicates().reset_index(drop=True)

cars_table
# Out:
#                 id manufacturer                     model drive  cylinders  \
# 0       7316814884          gmc  sierra 1500 crew cab slt   fwd          8
# 1       7316814758    chevrolet            silverado 1500   fwd          8
# 2       7316814989    chevrolet       silverado 1500 crew   4wd          8
# 3       7316743432       toyota      tundra double cab sr   4wd          8
# 4       7316356412         ford                 f-150 xlt   rwd          6
# ...            ...          ...                       ...   ...        ...
# 426848  7301591192       nissan         maxima s sedan 4d   fwd          6
# 426849  7301591187        volvo  s60 t5 momentum sedan 4d   fwd          6
# 426850  7301591147     cadillac          xt4 sport suv 4d   fwd          4
# 426851  7301591140        lexus           es 350 sedan 4d   fwd          6
# 426852  7301591129          bmw  4 series 430i gran coupe   rwd          4
#
#        transmission paint_color  car_id
# 0         automatic       white       1
# 1         automatic        blue       2
# 2         automatic         red       3
# 3         automatic         red       4
# 4         automatic       black       5
# ...             ...         ...     ...
# 426848    automatic         red    1099
# 426849    automatic         red      56
# 426850    automatic       white      28
# 426851    automatic      silver    1295
# 426852    automatic       white    4904
#
# [426853 rows x 8 columns]

# %%
colors = df["paint_color"].dropna().unique()
colors_table = pd.DataFrame(colors, columns=["color"])

hex_dict = {
    'black': '#000000',
    'blue': '#0000FF',
    'brown': '#A52A2A',
    'green': '#008000',
    'grey': '#808080',
    'orange': '#FFA500',
    'purple': '#800080',
    'red': '#FF0000',
    'silver': '#C0C0C0',
    'white': '#FFFFFF',
    'yellow': '#FFFF00',
}

colors_table['hex'] = colors_table['color'].map(hex_dict)

colors_table
# Out:
#      color      hex
# 0    white  #FFFFFF
# 1     blue  #0000FF
# 2      red  #FF0000
# 3    black  #000000
# 4   silver  #C0C0C0
# 5     grey  #808080
# 6    brown  #A52A2A
# 7   yellow  #FFFF00
# 8   orange  #FFA500
# 9    green  #008000
# 10  purple  #800080

# %%
fake = Faker()

num_users = 500

user_data = {
    'user_id': random.sample(range(10000000, 100000000), num_users), # 8 digit user_id
    'first_name': [fake.first_name() for _ in range(num_users)],
    'last_name': [fake.last_name() for _ in range(num_users)],
    'email': [fake.email() for _ in range(num_users)],
    'date_of_birth': [fake.date_of_birth(minimum_age=18, maximum_age=90) for _ in range(num_users)],
    'password': [fake.password(length=10, special_chars=True, digits=True, upper_case=True, lower_case=True) for _ in range(num_users)]
}

users_table = pd.DataFrame(user_data)
users_table
# Out:
#       user_id first_name last_name                        email date_of_birth  \
# 0    27371885      Stacy     Gross         austin62@example.com    1963-04-03
# 1    42312979      Kayla   Parrish           dlopez@example.com    1968-08-15
# 2    46296224       Dana     Cline      weberphilip@example.com    1979-09-18
# 3    38098518       Jose    Tucker       bairdapril@example.com    1946-03-09
# 4    58563569     Amanda    Miller  mcdonaldmiranda@example.net    1962-05-07
# ..        ...        ...       ...                          ...           ...
# 495  10810757      Linda       Lee           mark63@example.org    1998-03-29
# 496  73830688      James   Delgado     albertglover@example.org    1982-07-15
# 497  23946605    Charles    Hunter        claudia59@example.org    1960-07-02
# 498  44298622    Rebecca      Ward      jameschavez@example.net    1945-12-31
# 499  89760932      Julie   Gregory     mooremichele@example.com    1942-07-23
#
#        password
# 0    (OO$pl!Jk2
# 1    r+FQ+0PplH
# 2    4f6oN&pf(!
# 3    GMG8zXPf%^
# 4    (4K%gcV@Rb
# ..          ...
# 495  $6Szbsx0@b
# 496  j@Ka4@Nr3G
# 497  VS7^CqLB%B
# 498  @SdBii_u55
# 499  UG4tJql+!+
#
# [500 rows x 6 columns]

# %%
num_rentals = 1000

rental_data = {
    'rental_id': random.sample(range(1000000000, 10000000000), num_rentals), # 10 digit rental_id
    'car_id': [random.choice(cars_table['car_id']) for _ in range(num_rentals)],
    'user_id': [random.choice(users_table['user_id']) for _ in range(num_rentals)],
    'rent_date': [fake.date_this_year(before_today=True, after_today=False) for _ in range(num_rentals)],
}

num_active = num_rentals // 2
num_inactive = num_rentals - num_active

# active rentals
active_rent_dates = [fake.date_this_year(before_today=True, after_today=False) for _ in range(num_active)]
active_return_dates = [(pd.to_datetime(rent_date) + pd.to_timedelta(random.randint(1, 50), unit='d')).strftime('%Y-%m-%d')
                       for rent_date in active_rent_dates]

# inactive rentals
start_date = datetime.now() - timedelta(days=365 * 10)
inactive_rent_dates = [fake.date_between_dates(date_start=start_date, date_end=datetime.now() - timedelta(days=50))
                       for _ in range(num_inactive)]
inactive_return_dates = [(pd.to_datetime(rent_date) + pd.to_timedelta(random.randint(1, 50), unit='d')).strftime('%Y-%m-%d')
                         for rent_date in inactive_rent_dates]

rental_data['rent_date'] = active_rent_dates + inactive_rent_dates
rental_data['return_date'] = active_return_dates + inactive_return_dates
rental_data['status'] = ['active'] * num_active + ['inactive'] * num_inactive
rentals_table = pd.DataFrame(rental_data)
rentals_table = rentals_table.sample(frac=1).reset_index(drop=True)

rentals_table
# Out:
#       rental_id  car_id   user_id   rent_date return_date    status
# 0    1780144280    1655  93744066  2015-03-02  2015-03-31  inactive
# 1    2863448024    1173  51578546  2018-03-26  2018-05-05  inactive
# 2    6251532736    3397  12906399  2024-04-04  2024-04-22    active
# 3    5959827110     207  84124936  2020-08-11  2020-09-18  inactive
# 4    4099689566      33  63297241  2017-02-22  2017-03-05  inactive
# ..          ...     ...       ...         ...         ...       ...
# 995  3995186419     877  91882858  2014-11-24  2014-12-15  inactive
# 996  1608386795    3430  48888504  2024-04-23  2024-04-24    active
# 997  1760676985    5759  31215000  2024-04-12  2024-05-02    active
# 998  8292737800   37898  67900973  2024-01-17  2024-02-14    active
# 999  3156308279    2887  35262703  2024-02-03  2024-03-07    active
#
# [1000 rows x 6 columns]

# %%
listings_table = df[["id", "url", "region", "image_url", "description", "condition", "vin", "lat", "long", "state", "price", "posting_date"]]
listings_table["car_id"] = cars_table['car_id']

listings_table = listings_table.rename(columns={
    "url": "listing_url",
    "lat": "lat_id",
    "long": "long_id",
    "state": "state_id"
})

listings_table
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_15940\3592155776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_table["car_id"] = cars_table['car_id']
#                 id                                        listing_url  \
# 0       7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2       7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3       7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4       7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426848  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426849  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426850  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426851  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426852  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                                          image_url  \
# 0        auburn  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1        auburn  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2        auburn  https://images.craigslist.org/01212_jjirIWa0y0...
# 3        auburn  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4        auburn  https://images.craigslist.org/00404_l4loxHvdQe...
# ...         ...                                                ...
# 426848  wyoming  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426849  wyoming  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426850  wyoming  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426851  wyoming  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426852  wyoming  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description  condition  \
# 0       Carvana is the safer way to buy a car During t...       good
# 1       Carvana is the safer way to buy a car During t...       good
# 2       Carvana is the safer way to buy a car During t...       good
# 3       Carvana is the safer way to buy a car During t...       good
# 4       2013 F-150 XLT V6 4 Door. Good condition. Leve...  excellent
# ...                                                   ...        ...
# 426848  Carvana is the safer way to buy a car During t...       good
# 426849  Carvana is the safer way to buy a car During t...       good
# 426850  Carvana is the safer way to buy a car During t...       good
# 426851  Carvana is the safer way to buy a car During t...       good
# 426852  Carvana is the safer way to buy a car During t...       good
#
#                       vin     lat_id    long_id state_id  price  \
# 0       3GTP1VEC4EG551563  32.590000 -85.480000       al  33590
# 1       1GCSCSE06AZ123805  32.590000 -85.480000       al  22590
# 2       3GCPWCED5LG130317  32.590000 -85.480000       al  39590
# 3       5TFRM5F17HX120972  32.590000 -85.480000       al  30990
# 4       UZ6APLWVZM7ZN6W63  32.592000 -85.518900       al  15000
# ...                   ...        ...        ...      ...    ...
# 426848  1N4AA6AV6KC367801  33.786500 -84.445400       wy  23590
# 426849  7JR102FKXLG042696  33.786500 -84.445400       wy  30590
# 426850  1GYFZFR46LF088296  33.779214 -84.411811       wy  34990
# 426851  58ABK1GG4JU103853  33.786500 -84.445400       wy  28990
# 426852  WBA4J1C58KBM14708  33.779214 -84.411811       wy  30590
#
#               posting_date  car_id
# 0      2024-04-27 18:30:59       1
# 1      2024-02-28 18:59:04       2
# 2      2024-05-09 23:21:35       3
# 3      2023-11-01 02:05:15       4
# 4      2024-05-19 07:11:15       5
# ...                    ...     ...
# 426848 2023-11-09 23:35:42    1099
# 426849 2023-09-17 08:04:41      56
# 426850 2023-11-18 23:26:41      28
# 426851 2024-02-01 14:48:21    1295
# 426852 2023-10-26 18:57:54    4904
#
# [426853 rows x 13 columns]

# %%
import pandas as pd

state_data = {
    'state_id': ['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
                   'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'ma',
                   'mi', 'mn', 'ms', 'mo', 'mt', 'nc', 'ne', 'nv', 'nj', 'nm', 'ny',
                   'nh', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
                   'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'],
    'state_name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 
                   'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 
                   'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 
                   'Montana', 'North Carolina', 'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'New Hampshire', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
                   'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'time_zone': ['Central', 'Alaska', 'Mountain', 'Central', 'Pacific', 'Mountain', 'Eastern', 'Eastern', 'Eastern', 'Eastern', 
                  'Eastern', 'Hawaii-Aleutian', 'Mountain', 'Central', 'Eastern', 'Central', 'Central', 'Eastern', 'Central', 
                  'Eastern', 'Eastern', 'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Central', 
                  'Pacific', 'Eastern', 'Mountain', 'Eastern', 'Eastern', 'Central', 'Eastern', 'Central', 'Pacific', 'Eastern', 
                  'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Eastern', 'Pacific', 'Eastern', 
                  'Central', 'Mountain']
}

states_table = pd.DataFrame(state_data)
states_table
# Out:
#    state_id            state_name        time_zone
# 0        al               Alabama          Central
# 1        ak                Alaska           Alaska
# 2        az               Arizona         Mountain
# 3        ar              Arkansas          Central
# 4        ca            California          Pacific
# 5        co              Colorado         Mountain
# 6        ct           Connecticut          Eastern
# 7        dc  District of Columbia          Eastern
# 8        de              Delaware          Eastern
# 9        fl               Florida          Eastern
# 10       ga               Georgia          Eastern
# 11       hi                Hawaii  Hawaii-Aleutian
# 12       id                 Idaho         Mountain
# 13       il              Illinois          Central
# 14       in               Indiana          Eastern
# 15       ia                  Iowa          Central
# 16       ks                Kansas          Central
# 17       ky              Kentucky          Eastern
# 18       la             Louisiana          Central
# 19       me                 Maine          Eastern
# 20       md              Maryland          Eastern
# 21       ma         Massachusetts          Eastern
# 22       mi              Michigan          Eastern
# 23       mn             Minnesota          Central
# 24       ms           Mississippi          Central
# 25       mo              Missouri          Central
# 26       mt               Montana         Mountain
# 27       nc        North Carolina          Eastern
# 28       ne              Nebraska          Central
# 29       nv                Nevada          Pacific
# 30       nj            New Jersey          Eastern
# 31       nm            New Mexico         Mountain
# 32       ny              New York          Eastern
# 33       nh         New Hampshire          Eastern
# 34       nd          North Dakota          Central
# 35       oh                  Ohio          Eastern
# 36       ok              Oklahoma          Central
# 37       or                Oregon          Pacific
# 38       pa          Pennsylvania          Eastern
# 39       ri          Rhode Island          Eastern
# 40       sc        South Carolina          Eastern
# 41       sd          South Dakota          Central
# 42       tn             Tennessee          Central
# 43       tx                 Texas          Central
# 44       ut                  Utah         Mountain
# 45       vt               Vermont          Eastern
# 46       va              Virginia          Eastern
# 47       wa            Washington          Pacific
# 48       wv         West Virginia          Eastern
# 49       wi             Wisconsin          Central
# 50       wy               Wyoming         Mountain

# %%
num_favorites = 750
favorite_data = {
    'id': [random.choice(cars_table['id']) for _ in range(num_favorites)],
    'user_id': [random.choice(users_table['user_id']) for _ in range(num_favorites)]
}

favorites_table = pd.DataFrame(favorite_data)
favorites_table['car_id'] = favorites_table['id'].map(cars_table.set_index('id')['car_id'].to_dict())

favorites_table
# Out:
#              id   user_id  car_id
# 0    7305418459  80018752    9197
# 1    7305728342  42184623   16401
# 2    7306912951  49050619    1057
# 3    7303865008  71804862       2
# 4    7309195248  37465766   15063
# ..          ...       ...     ...
# 745  7312748225  18170064    3389
# 746  7315441300  72344077   23859
# 747  7312301950  53544834    1505
# 748  7316244995  41509111    7061
# 749  7312917662  27623955     297
#
# [750 rows x 3 columns]

# %%
# # save da files
# cars_table.to_csv('cars_table.csv', index=False)
# colors_table.to_csv('colors_table.csv', index=False)
# users_table.to_csv('users_table.csv', index=False)
# rentals_table.to_csv('rentals_table.csv', index=False)
# listings_table.to_csv('listings_table.csv', index=False)
# favorites_table.to_csv('favorites_table.csv', index=False)
# states_table.to_csv('states_table.csv', index=False)

# %% [markdown]
# # Sample Dataset

# %%
sample_df = df.sample(n=50).reset_index(drop=True)
sample_df
# Out:
#             id                                                url  \
# 0   7304740863  https://columbia.craigslist.org/cto/d/cayce-08...
# 1   7315418880  https://dallas.craigslist.org/mdf/cto/d/grand-...
# 2   7308351653  https://clarksville.craigslist.org/ctd/d/chatt...
# 3   7316046880  https://boise.craigslist.org/ctd/d/boise-2009-...
# 4   7316681092  https://danville.craigslist.org/ctd/d/eden-202...
# 5   7306586367  https://pueblo.craigslist.org/cto/d/fort-garla...
# 6   7316338679  https://sacramento.craigslist.org/ctd/d/sacram...
# 7   7316636488  https://grandrapids.craigslist.org/cto/d/belmo...
# 8   7316924521  https://greenville.craigslist.org/ctd/d/kerner...
# 9   7313478798  https://albuquerque.craigslist.org/cto/d/albuq...
# 10  7303213510  https://fortcollins.craigslist.org/ctd/d/longm...
# 11  7315009988  https://orlando.craigslist.org/ctd/d/2005-lexu...
# 12  7308575011  https://columbus.craigslist.org/ctd/d/columbus...
# 13  7306921296  https://greensboro.craigslist.org/ctd/d/kerner...
# 14  7309726002  https://utica.craigslist.org/ctd/d/utica-2015-...
# 15  7313955236  https://stillwater.craigslist.org/ctd/d/wellst...
# 16  7310224425  https://hartford.craigslist.org/ctd/d/athol-sa...
# 17  7315541653  https://chicago.craigslist.org/nch/ctd/d/skoki...
# 18  7312873544  https://fayar.craigslist.org/cto/d/salem-toyot...
# 19  7312672944  https://siouxfalls.craigslist.org/ctd/d/sioux-...
# 26  2014.0      chevrolet                suburban ltz 1500 4x4       good
# 27  2003.0           jeep                              liberty  excellent
# 28  2019.0           ford                  mustang gt coupe 2d       good
# 29  2016.0            ram                         1500 laramie  excellent
# 30  1998.0        porsche                              boxster   like new
# 31  2014.0          lexus                      gs 350 sedan 4d       good
# 32  2013.0  mercedes-benz                            glk-class   like new
# 33  1994.0           ford                                 f700  excellent
# 34  2010.0         toyota                             scion tc       good
# 35  1935.0           ford                            2dr sedan  excellent
# 36  2011.0       chrysler                                  200       good
# 37  2017.0       cadillac                            ct6 sedan       good
# 38  2006.0      chevrolet                               cobalt       good
# 39  2008.0          honda                               accord  excellent
# 40  2013.0           ford                               escape  excellent
# 41  2000.0      chevrolet                                   x3   like new
# 42  2020.0          rover                      discovery sport       good
# 43  2019.0           audi          q8 premium sport utility 4d       good
# 44  2015.0            bmw           3 series 328d xdrive sport       good
# 45  2016.0           ford                                f-250       good
# 46  2010.0           jeep                             wrangler  excellent
# 47  2015.0           ford                      transit connect       good
# 48  2018.0          lexus              nx 300 sport utility 4d       good
# 49  2015.0         subaru                             forester  excellent
#
#     cylinders  ...                vin  drive       type paint_color  \
# 0           8  ...  FX30XM2WS7X6UVFSJ    rwd      sedan       black
# 1           4  ...  Y284C5GUSFBRZDGTY    fwd      coupe        blue
# 2           8  ...  5TFRX5GN0KX157328    fwd     pickup      silver
# 3           5  ...  3VWRM71K39M097027    fwd      sedan       black
# 4           4  ...  1FTER1FH1MLD35335    4wd      sedan        grey
# 5           6  ...  VK0SZ95D6K9K1EG7L    4wd      sedan       green
# 6           4  ...  1N4BL4CV6LC183654    fwd      sedan       white
# 7           6  ...  RDVY51W4F9NPK6H87    fwd        SUV      silver
# 8           6  ...  VAMBB4VN902GHNCFG    4wd        SUV       black
# 9           4  ...  8KH50XCH7A5AAVRVM    4wd      wagon       white
# 10          6  ...  1J4FA49S85P386548    4wd        SUV       black
# 11          8  ...  T9RK5U8B2LBRFN66C    4wd        SUV       black
# 12          4  ...  WKRF787VUAM5JMXLJ    fwd      coupe       black
# 13          8  ...  PMBZ1R6G1WRNFTJ5N    rwd        SUV        blue
# 14          8  ...  5FRYD4H83FB028683    rwd        SUV       black
# 15          6  ...  1C4RJEAG5FC879273    rwd        SUV       white
# 16          6  ...  YJV66VN03UEBGZLYC    rwd      sedan       black
# 17          5  ...  93480XBGBAS0MSX5S    4wd      sedan       white
# 18          8  ...  TV1J1Y3SUCNS5NXN4    4wd        SUV       white
# 19          6  ...  450MZWY4TM89UY76G    fwd        van      silver
# 20          6  ...  U2NL2M4UKFA00G8SW    4wd        SUV       black
# 21          8  ...  1GCRKSE72CZ239990    4wd      sedan      silver
# 22          6  ...  3C6TRVAG3HE552405    fwd        van       white
# 23          6  ...  1C4GJWBG6CL153249    4wd        SUV         red
# 24          8  ...  1FD0W5HT9BEC16926    4wd     pickup         red
# 25          8  ...  5NPEJ4J2XLH027708    fwd      sedan       black
# 26          8  ...  1GNSKKE7XER149806    rwd     pickup       white
# 15  -96.953910 2023-09-17 22:32:09
# 16  -72.226700 2024-04-23 14:01:45
# 17  -87.752954 2023-12-30 05:03:29
# 18  -91.875900 2023-08-15 20:15:02
# 19  -96.817700 2024-01-18 00:20:13
# 20  -74.092762 2024-04-28 11:01:22
# 21  -71.762086 2024-05-04 13:14:36
# 22  -86.389644 2023-08-20 00:12:28
# 23  -91.120000 2023-08-30 01:17:02
# 24  -76.909548 2024-02-09 17:16:55
# 25  -82.370000 2024-04-24 08:49:38
# 26 -123.055986 2024-04-01 17:36:19
# 27 -119.117030 2023-07-03 07:19:15
# 28  -97.070000 2024-02-06 04:11:49
# 29  -80.253800 2024-02-14 01:25:02
# 30 -115.256600 2023-07-14 01:47:34
# 31  -81.850000 2024-04-10 15:38:05
# 32  -96.893780 2023-08-18 16:18:17
# 33  -72.576885 2023-11-24 13:19:02
# 34 -121.257580 2024-04-11 00:41:48
# 35 -122.339826 2024-02-19 10:41:29
# 36  -87.633814 2023-10-28 12:42:05
# 37  -96.023096 2023-07-19 18:09:54
# 38  -84.549458 2023-12-04 22:40:23
# 39  -75.145600 2023-06-27 14:34:26
# 40  -76.379804 2024-01-28 23:45:13
# 41  -78.370000 2024-03-30 12:38:41
# 42  -87.980000 2023-09-05 13:26:09
# 43  -78.720000 2023-06-22 07:50:54
# 44  -82.320000 2023-08-07 20:24:57
# 45  -97.839307 2024-03-14 23:39:51
# 46  -76.844044 2024-06-05 08:34:00
# 47 -120.974900 2023-09-23 04:14:46
# 48  -84.445400 2024-05-01 17:59:32
# 49  -86.116313 2024-03-01 17:39:14
#
# [50 rows x 24 columns]

# %%
unique_cars = sample_df[['manufacturer', 'model']].drop_duplicates().reset_index(drop=True)
unique_cars['car_id'] = range(1, len(unique_cars) + 1)

sample_cars_table = sample_df[["id", "manufacturer", "model", "drive", "cylinders", "transmission", "paint_color"]]
sample_cars_table = sample_cars_table.merge(unique_cars, on=['manufacturer', 'model'], how='left').drop_duplicates().reset_index(drop=True)
sample_cars_table
# Out:
#             id   manufacturer                                model drive  \
# 0   7304740863          dodge                              avenger   rwd
# 1   7315418880          mazda                                    3   fwd
# 2   7308351653         toyota                 tacoma access cab sr   fwd
# 3   7316046880     volkswagen                             jetta se   fwd
# 4   7316681092           ford                               ranger   4wd
# 5   7306586367           ford                               escape   4wd
# 6   7316338679         nissan                        altima 2.5 sr   fwd
# 7   7316636488        hyundai                             santa fe   fwd
# 8   7316924521            bmw                                   x5   4wd
# 9   7313478798         subaru                              putback   4wd
# 10  7303213510           jeep                             wrangler   4wd
# 11  7315009988          lexus                               lx 470   4wd
# 12  7308575011          honda                            civic cpe   fwd
# 13  7306921296          dodge                          charger sxt   rwd
# 14  7309726002          acura             mdx sh-awd sport utility   rwd
# 15  7313955236           jeep                       grand cherokee   rwd
# 16  7310224425          dodge                              charger   rwd
# 17  7315541653          volvo                               s60 t5   4wd
# 18  7312873544         toyota                                 rav4   4wd
# 19  7312672944          honda                              odyssey   fwd
# 20  7315040127           ford                     explorer limited   4wd
# 21  7303037235      chevrolet                       silverado 1500   4wd
# 22  7311648611            ram                  promaster cargo van   fwd
# 23  7304052561           jeep                wrangler sahara sport   4wd
# 24  7307911484           ford  f-550 crew cab flat bed xlt 4x4 drw   4wd
# 25  7303760016        hyundai             sonata sel plus sedan 4d   fwd
# 26  7310649382      chevrolet                suburban ltz 1500 4x4   rwd
# 27  7313271104           jeep                              liberty   rwd
# 28  7312322985           ford                  mustang gt coupe 2d   rwd
# 29  7314804499            ram                         1500 laramie   4wd
# 30  7315127572        porsche                              boxster   rwd
# 31  7305096036          lexus                      gs 350 sedan 4d   rwd
# 32  7315298657  mercedes-benz                            glk-class   4wd
# 33  7316731256           ford                                 f700   4wd
# 34  7316352843         toyota                             scion tc   fwd
# 35  7314953068           ford                            2dr sedan   4wd
# 36  7314088035       chrysler                                  200   fwd
# 37  7313904361       cadillac                            ct6 sedan   4wd
# 38  7304707506      chevrolet                               cobalt   fwd
# 39  7313998734          honda                               accord   fwd
# 40  7314766451           ford                               escape   4wd
# 41  7316695011      chevrolet                                   x3   4wd
# 42  7306651911          rover                      discovery sport   4wd
# 43  7303681285           audi          q8 premium sport utility 4d   fwd
# 44  7310962031            bmw           3 series 328d xdrive sport   4wd
# 45  7310988798           ford                                f-250   4wd
# 46  7303286315           jeep                             wrangler   4wd
# 47  7310007114           ford                      transit connect   4wd
# 48  7309697685          lexus              nx 300 sport utility 4d   4wd
# 49  7308388950         subaru                             forester   4wd
#
#     cylinders transmission paint_color  car_id
# 0           8    automatic       black       1
# 1           4    automatic        blue       2
# 2           8    automatic      silver       3
# 3           5    automatic       black       4
# 4           4    automatic        grey       5
# 5           6    automatic       green       6
# 6           4    automatic       white       7
# 7           6    automatic      silver       8
# 8           6    automatic       black       9
# 9           4    automatic       white      10
# 10          6       manual       black      11
# 11          8    automatic       black      12
# 12          4    automatic       black      13
# 13          8    automatic        blue      14
# 14          8    automatic       black      15
# 15          6    automatic       white      16
# 16          6    automatic       black      17
# 17          5    automatic       white      18
# 18          8    automatic       white      19
# 19          6    automatic      silver      20
# 20          6    automatic       black      21
# 21          8    automatic      silver      22
# 22          6    automatic       white      23
# 23          6    automatic         red      24
# 24          8    automatic         red      25
# 25          8    automatic       black      26
# 26          8    automatic       white      27
# 27          6    automatic       black      28
# 28          8    automatic       black      29
# 29          8    automatic       black      30
# 30          6    automatic       white      31
# 31          6    automatic       white      32
# 32          8    automatic      silver      33
# 33          6    automatic      silver      34
# 34          4    automatic       white      35
# 35          4    automatic      silver      36
# 36          4    automatic       black      37
# 37          6    automatic         red      38
# 38          4       manual         red      39
# 39          4    automatic       white      40
# 40          4    automatic       white       6
# 41          4    automatic       white      41
# 42          8    automatic       white      42
# 43          8    automatic       black      43
# 44          8    automatic       black      44
# 45          6    automatic       black      45
# 46          4       manual       black      11
# 47          6    automatic       white      46
# 48          8    automatic       white      47
# 49          4    automatic      silver      48

# %%
colors = df["paint_color"].dropna().unique()
colors_table = pd.DataFrame(colors, columns=["color"])

hex_dict = {
    'black': '#000000',
    'blue': '#0000FF',
    'brown': '#A52A2A',
    'green': '#008000',
    'grey': '#808080',
    'orange': '#FFA500',
    'purple': '#800080',
    'red': '#FF0000',
    'silver': '#C0C0C0',
    'white': '#FFFFFF',
    'yellow': '#FFFF00',
}

colors_table['hex'] = colors_table['color'].map(hex_dict)

colors_table
# Out:
#      color      hex
# 0    white  #FFFFFF
# 1     blue  #0000FF
# 2      red  #FF0000
# 3    black  #000000
# 4   silver  #C0C0C0
# 5     grey  #808080
# 6    brown  #A52A2A
# 7   yellow  #FFFF00
# 8   orange  #FFA500
# 9    green  #008000
# 10  purple  #800080

# %%
fake = Faker()

num_users = 10

user_data = {
    'user_id': random.sample(range(10000000, 100000000), num_users), # 8 digit user_id
    'first_name': [fake.first_name() for _ in range(num_users)],
    'last_name': [fake.last_name() for _ in range(num_users)],
    'email': [fake.email() for _ in range(num_users)],
    'date_of_birth': [fake.date_of_birth(minimum_age=18, maximum_age=90) for _ in range(num_users)],
    'password': [fake.password(length=10, special_chars=True, digits=True, upper_case=True, lower_case=True) for _ in range(num_users)]
}

sample_users_table = pd.DataFrame(user_data)
sample_users_table
# Out:
#     user_id first_name  last_name                         email date_of_birth  \
# 0  58212432      Chris      Lewis    rachaelbradley@example.org    1952-01-25
# 1  60563857       John      Green          pbaldwin@example.org    2005-06-29
# 2  58474563     Amanda     Miller        sydneypage@example.net    1951-03-12
# 3  45361748    Richard  Hendricks           aaron03@example.org    1949-07-21
# 4  30936609      Peter      Lewis  carpenterraymond@example.net    1985-07-26
# 5  11543547       Jill     Valdez         fgriffith@example.net    1950-10-26
# 6  67020190    Anthony       Long      josephfowler@example.org    1939-01-17
# 7  78258299   Gabriela      Lucas            sara21@example.net    1987-03-17
# 8  22288084       Mark    Sanchez          brandy59@example.net    1995-09-29
# 9  32967301    Melissa       Bell  christophercurry@example.org    1962-06-11
#
#      password
# 0  AT49GoK4$2
# 1  $gyt#VOl^2
# 2  @m%OWIHja6
# 3  R3BSuHWA^V
# 4  W_KDE9Bx@2
# 5  YGaV2YoJ#I
# 6  *i0Ga(tP3L
# 7  d1LhAkl%@p
# 8  *@P$6Co%0&
# 9  +G2u3RNnV4

# %%
num_rentals = 50

rental_data = {
    'rental_id': random.sample(range(1000000000, 10000000000), num_rentals), # 10 digit rental_id
    'car_id': [random.choice(sample_cars_table['car_id']) for _ in range(num_rentals)],
    'user_id': [random.choice(sample_users_table['user_id']) for _ in range(num_rentals)],
    'rent_date': [fake.date_this_year(before_today=True, after_today=False) for _ in range(num_rentals)],
}

num_active = num_rentals // 2
num_inactive = num_rentals - num_active

# active rentals
active_rent_dates = [fake.date_this_year(before_today=True, after_today=False) for _ in range(num_active)]
active_return_dates = [(pd.to_datetime(rent_date) + pd.to_timedelta(random.randint(1, 50), unit='d')).strftime('%Y-%m-%d')
                       for rent_date in active_rent_dates]

# inactive rentals
start_date = datetime.now() - timedelta(days=365 * 10)
inactive_rent_dates = [fake.date_between_dates(date_start=start_date, date_end=datetime.now() - timedelta(days=50))
                       for _ in range(num_inactive)]
inactive_return_dates = [(pd.to_datetime(rent_date) + pd.to_timedelta(random.randint(1, 50), unit='d')).strftime('%Y-%m-%d')
                         for rent_date in inactive_rent_dates]

rental_data['rent_date'] = active_rent_dates + inactive_rent_dates
rental_data['return_date'] = active_return_dates + inactive_return_dates
rental_data['status'] = ['active'] * num_active + ['inactive'] * num_inactive
sample_rentals_table = pd.DataFrame(rental_data)
sample_rentals_table = sample_rentals_table.sample(frac=1).reset_index(drop=True)

sample_rentals_table
# Out:
#      rental_id  car_id   user_id   rent_date return_date    status
# 0   7055645981      44  78258299  2014-06-26  2014-07-13  inactive
# 1   6121198645      31  58474563  2019-01-22  2019-02-24  inactive
# 2   3118355110       2  30936609  2024-04-01  2024-05-03    active
# 3   7452487094      24  22288084  2020-06-14  2020-06-25  inactive
# 4   3072036255      44  58474563  2024-05-21  2024-06-25    active
# 5   7073838007      40  22288084  2024-04-12  2024-05-12    active
# 6   2945251529      38  60563857  2020-09-30  2020-11-10  inactive
# 7   9579182778      16  22288084  2022-09-22  2022-10-31  inactive
# 8   6209742775      19  60563857  2024-05-08  2024-06-03    active
# 9   1423607859      35  32967301  2024-04-08  2024-05-13    active
# 10  4160052953       2  67020190  2023-08-09  2023-09-04  inactive
# 11  7551837549      35  67020190  2024-05-12  2024-06-24    active
# 12  7824351477      45  11543547  2024-04-18  2024-05-23    active
# 13  6544261644       2  67020190  2019-05-04  2019-05-05  inactive
# 14  7224720469      33  32967301  2016-11-02  2016-11-15  inactive
# 15  7636942516      38  30936609  2024-06-10  2024-06-21    active
# 16  7252631323      12  78258299  2024-01-24  2024-02-07    active
# 17  2220945527      20  78258299  2024-04-16  2024-05-09    active
# 18  4466465265      44  30936609  2023-08-14  2023-08-22  inactive
# 19  9643887676      31  58474563  2024-02-08  2024-02-22    active
# 20  3322544034      42  78258299  2022-03-05  2022-04-05  inactive
# 21  8211024286      28  60563857  2024-05-10  2024-05-31    active
# 22  7171117364      29  45361748  2024-03-09  2024-04-01    active
# 23  6553560919      15  78258299  2015-05-11  2015-06-23  inactive
# 24  2503533268      34  45361748  2024-06-18  2024-07-18    active
# 25  6018210629      23  45361748  2024-05-12  2024-06-14    active
# 26  4044271981      18  58474563  2015-05-26  2015-05-28  inactive
# 27  8621696219      44  30936609  2016-03-17  2016-04-04  inactive
# 28  6438309101      33  58474563  2017-06-01  2017-06-06  inactive
# 29  9845003277      16  60563857  2024-02-08  2024-02-11    active
# 30  5138243358      34  67020190  2024-01-13  2024-02-20    active
# 31  8861057554      48  30936609  2023-08-24  2023-09-11  inactive
# 32  6547389302       1  58212432  2024-04-03  2024-04-18    active
# 33  7424333767      21  30936609  2015-12-24  2016-01-07  inactive
# 34  7216024680      38  32967301  2015-04-24  2015-06-12  inactive
# 35  5293544805      11  58474563  2014-08-28  2014-10-13  inactive
 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
                   'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'],
    'state_name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 
                   'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 
                   'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 
                   'Montana', 'North Carolina', 'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'New Hampshire', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
                   'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'time_zone': ['Central', 'Alaska', 'Mountain', 'Central', 'Pacific', 'Mountain', 'Eastern', 'Eastern', 'Eastern', 'Eastern', 
                  'Eastern', 'Hawaii-Aleutian', 'Mountain', 'Central', 'Eastern', 'Central', 'Central', 'Eastern', 'Central', 
                  'Eastern', 'Eastern', 'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Central', 
                  'Pacific', 'Eastern', 'Mountain', 'Eastern', 'Eastern', 'Central', 'Eastern', 'Central', 'Pacific', 'Eastern', 
                  'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Eastern', 'Pacific', 'Eastern', 
                  'Central', 'Mountain']
}

states_table = pd.DataFrame(state_data)
states_table
# Out:
#    state_id            state_name        time_zone
# 0        al               Alabama          Central
# 1        ak                Alaska           Alaska
# 2        az               Arizona         Mountain
# 3        ar              Arkansas          Central
# 4        ca            California          Pacific
# 5        co              Colorado         Mountain
# 6        ct           Connecticut          Eastern
# 7        dc  District of Columbia          Eastern
# 8        de              Delaware          Eastern
# 9        fl               Florida          Eastern
# 10       ga               Georgia          Eastern
# 11       hi                Hawaii  Hawaii-Aleutian
# 12       id                 Idaho         Mountain
# 13       il              Illinois          Central
# 14       in               Indiana          Eastern
# 15       ia                  Iowa          Central
# 16       ks                Kansas          Central
# 17       ky              Kentucky          Eastern
# 18       la             Louisiana          Central
# 19       me                 Maine          Eastern
# 20       md              Maryland          Eastern
# 21       ma         Massachusetts          Eastern
# 22       mi              Michigan          Eastern
# 23       mn             Minnesota          Central
# 24       ms           Mississippi          Central
# 25       mo              Missouri          Central
# 26       mt               Montana         Mountain
# 27       nc        North Carolina          Eastern
# 28       ne              Nebraska          Central
# 29       nv                Nevada          Pacific
# 30       nj            New Jersey          Eastern
# 31       nm            New Mexico         Mountain
# 32       ny              New York          Eastern
# 33       nh         New Hampshire          Eastern
# 34       nd          North Dakota          Central
# 35       oh                  Ohio          Eastern
# 36       ok              Oklahoma          Central
# 37       or                Oregon          Pacific
# 38       pa          Pennsylvania          Eastern
# 39       ri          Rhode Island          Eastern
# 40       sc        South Carolina          Eastern
# 41       sd          South Dakota          Central
# 42       tn             Tennessee          Central
# 43       tx                 Texas          Central
# 44       ut                  Utah         Mountain
# 45       vt               Vermont          Eastern
# 46       va              Virginia          Eastern
# 47       wa            Washington          Pacific
# 48       wv         West Virginia          Eastern
# 49       wi             Wisconsin          Central
# 50       wy               Wyoming         Mountain

# %%
num_favorites = 20
favorite_data = {
    'id': [random.choice(sample_cars_table['id']) for _ in range(num_favorites)],
    'user_id': [random.choice(sample_users_table['user_id']) for _ in range(num_favorites)]
}

sample_favorites_table = pd.DataFrame(favorite_data)
sample_favorites_table['car_id'] = sample_favorites_table['id'].map(sample_cars_table.set_index('id')['car_id'].to_dict())

sample_favorites_table
# Out:
#             id   user_id  car_id
# 0   7313271104  58474563      28
# 1   7306921296  30936609      14
# 2   7309726002  11543547      15
# 3   7316695011  11543547      41
# 4   7315541653  32967301      18
# 5   7315127572  67020190      31
# 6   7315298657  78258299      33
# 7   7306651911  45361748      42
# 8   7306586367  45361748       6
# 9   7315418880  60563857       2
# 10  7303760016  58212432      26
# 11  7314088035  58212432      37
# 12  7306651911  78258299      42
# 13  7307911484  11543547      25
# 14  7312672944  22288084      20
# 15  7316681092  78258299       5
# 16  7303760016  11543547      26
# 17  7306586367  58474563       6
# 18  7316731256  58474563      34
# 19  7303213510  45361748      11

# %%
# # save da files
# cars_table.to_csv('cars_table.csv', index=False)
# colors_table.to_csv('colors_table.csv', index=False)
# users_table.to_csv('users_table.csv', index=False)
# rentals_table.to_csv('rentals_table.csv', index=False)
# listings_table.to_csv('listings_table.csv', index=False)
# favorites_table.to_csv('favorites_table.csv', index=False)
# states_table.to_csv('states_table.csv', index=False)

# %% [markdown]
# ### Data Summaries

# %%
lengths = []
for i in (df["url"] + df["image_url"]):
    lengths.append(len(str(i)))

max(lengths)
# Out:
# 169

# %%
# lat and long
max_lat = max(df["lat"].unique())
min_lat = min(df["lat"].unique())

max_long = max(df["long"].unique())
min_long = min(df["long"].unique())

print("lat: [", min_lat, ",", max_lat, "] long: [", min_long, ",", max_long, "]")
# Out:
# lat: [ -84.122245 , 82.390818 ] long: [ -159.827728 , 173.885502 ]

# %%
df["state"].dropna().unique()
# Out:
# array(['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
#        'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'ma',
#        'mi', 'mn', 'ms', 'mo', 'mt', 'nc', 'ne', 'nv', 'nj', 'nm', 'ny',
#        'nh', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
#        'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'], dtype=object)

# %%
df["condition"].dropna().unique()
# Out:
# array(['good', 'excellent', 'fair', 'like new', 'new', 'salvage'],
#       dtype=object)

# %%
user_favorites = favorites_table[favorites_table['userID'] == 'user_25764002']
user_favorites
# Out:
#                                favoriteID          id         userID
# 2    ee48c532-74cb-441b-866e-bc80d93b2983  7305679700  user_25764002
# 62   8bc0a3ef-2b21-4166-a4f3-3c71340284a1  7315916207  user_25764002
# 432  70b71a2d-2668-4515-858b-43cb648357db  7316856596  user_25764002
# 519  f1b6b231-3410-4140-aad3-2087e9e2f1a9  7313105260  user_25764002

# %%
len(df['manufacturer'].unique())
# Out:
# 42

# %%
df['model'].unique()
# Out:
# array(['sierra 1500 crew cab slt', 'silverado 1500',
#        'silverado 1500 crew', ..., 'gand wagoneer', '96 Suburban',
#        'Paige Glenbrook Touring'], dtype=object)

# %%
len(df['model'].unique())
# Out:
# 29667
