# %% [markdown]
# # Production Dataset

# %%
import pandas as pd
import numpy as np
import uuid
import random
from faker import Faker
import string
from datetime import datetime, timedelta, date

# %%
df = pd.read_csv("vehicles.csv")

# %%
def fill_na(column):
    actual = column.dropna().tolist()
    return column.apply(lambda x: x if pd.notna(x) else random.choice(actual))

def fill_na_vin(column):
    actual = column.dropna().tolist()
    vin_chars = string.ascii_uppercase.replace('I', '').replace('O', '').replace('Q', '') + string.digits

    def generate_random_vin():
        return ''.join(random.choices(vin_chars, k=17))
    
    return column.apply(lambda x: x if pd.notna(x) else generate_random_vin())

def generate_random_dates(n, start_date, end_date):
    start_u = start_date.value // 10**9
    end_u = end_date.value // 10**9
    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
df = df[27:]
df = df.reset_index().drop(["county", "size", "index"], axis=1)

# %%
fake = Faker()

df['drive'] = fill_na(df['drive'])
df['cylinders'] = fill_na(df['cylinders'])
df['paint_color'] = fill_na(df['paint_color'])
df['model'] = fill_na(df['model'])
df['manufacturer'] = fill_na(df['manufacturer'])
df['condition'] = fill_na(df['condition'])
df['fuel'] = fill_na(df['fuel'])
df['type'] = fill_na(df['type'])
df['VIN'] = fill_na_vin(df['VIN'])
df['description'] = [fake.text(max_nb_chars=200) for _ in range(len(df))]

avg_price = df["price"].mean()
df["price"] = (df["price"] / avg_price) * 200

df['cylinders'] = df['cylinders'].str.extract('(\d+)').astype(float)
df['cylinders'].fillna(df['cylinders'].dropna().sample(n=1).values[0], inplace=True)
df['cylinders'] = df['cylinders'].astype(int)


df['paint_color'] = df['paint_color'].replace('custom', 'white')
df['transmission'] = df['transmission'].replace('other', 'automatic')

df = df.rename(columns={
    "VIN": "vin"
})

end_date = pd.to_datetime('now')
start_date = end_date - pd.DateOffset(years=1)
df['posting_date'] = generate_random_dates(len(df), start_date, end_date)

df
# Out:
# C:\Users\siddh\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   result, tz_parsed = tslib.array_to_datetime(
#                 id                                                url  \
# 0       7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2       7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3       7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4       7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426848  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426849  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426850  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426851  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426852  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url       price    year  \
# 0        auburn   https://auburn.craigslist.org   89.331452  2014.0
# 1        auburn   https://auburn.craigslist.org   60.077330  2010.0
# 2        auburn   https://auburn.craigslist.org  105.288246  2020.0
# 3        auburn   https://auburn.craigslist.org   82.416841  2017.0
# 4        auburn   https://auburn.craigslist.org   39.891985  2013.0
# ...         ...                             ...         ...     ...
# 426848  wyoming  https://wyoming.craigslist.org   62.736795  2019.0
# 426849  wyoming  https://wyoming.craigslist.org   81.353055  2020.0
# 426850  wyoming  https://wyoming.craigslist.org   93.054704  2020.0
# 426851  wyoming  https://wyoming.craigslist.org   77.097910  2018.0
# 426852  wyoming  https://wyoming.craigslist.org   81.353055  2019.0
#
#        manufacturer                     model  condition  cylinders  ...  \
# 0               gmc  sierra 1500 crew cab slt       good          8  ...
# 1         chevrolet            silverado 1500       good          8  ...
# 2         chevrolet       silverado 1500 crew       good          8  ...
# 3            toyota      tundra double cab sr       good          8  ...
# 4              ford                 f-150 xlt  excellent          6  ...
# ...             ...                       ...        ...        ...  ...
# 426848       nissan         maxima s sedan 4d       good          6  ...
# 426849        volvo  s60 t5 momentum sedan 4d       good          8  ...
# 426850     cadillac          xt4 sport suv 4d       good          4  ...
# 426851        lexus           es 350 sedan 4d       good          6  ...
# 426852          bmw  4 series 430i gran coupe       good          8  ...
#
#                       vin  drive       type paint_color  \
# 0       3GTP1VEC4EG551563    fwd     pickup       white
# 1       1GCSCSE06AZ123805    rwd     pickup        blue
# 2       3GCPWCED5LG130317    fwd     pickup         red
# 3       5TFRM5F17HX120972    fwd     pickup         red
# 4       2WNSSJ7DTDE5HFGVG    rwd      truck       black
# ...                   ...    ...        ...         ...
# 426848  1N4AA6AV6KC367801    fwd      sedan         red
# 426849  7JR102FKXLG042696    fwd      sedan         red
# 426850  1GYFZFR46LF088296    fwd  hatchback       white
# 426851  58ABK1GG4JU103853    fwd      sedan      silver
# 426852  WBA4J1C58KBM14708    rwd      coupe      silver
#
#                                                 image_url  \
# 0       https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1       https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2       https://images.craigslist.org/01212_jjirIWa0y0...
# 3       https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4       https://images.craigslist.org/00404_l4loxHvdQe...
# ...                                                   ...
# 426848  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426849  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426850  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426851  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426852  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description state        lat  \
# 0       Anyone among build scientist. Hair rise feelin...    al  32.590000
# 1       Choice friend nearly keep activity poor. Food ...    al  32.590000
# 2       Carry research town establish. Begin total gov...    al  32.590000
# 3       Campaign itself style rich still exactly maybe...    al  32.590000
# 4       Floor reality because through. Table public ec...    al  32.592000
# ...                                                   ...   ...        ...
# 426848  Amount half bank race investment move final. D...    wy  33.786500
# 426849  Forward think up natural table beautiful milit...    wy  33.786500
# 426850  Those compare ground claim floor whatever. Sud...    wy  33.779214
# 426851  Give catch lawyer material. Process fight afte...    wy  33.786500
# 426852  Light pretty best alone month stay page. Peace...    wy  33.779214
#
#              long        posting_date
# 0      -85.480000 2023-11-26 10:12:55
# 1      -85.480000 2023-07-31 04:19:22
# 2      -85.480000 2023-11-13 15:09:34
# 3      -85.480000 2024-03-10 03:05:55
# 4      -85.518900 2023-10-25 10:25:54
# ...           ...                 ...
# 426848 -84.445400 2024-03-19 16:17:10
# 426849 -84.445400 2024-04-22 18:18:29
# 426850 -84.411811 2023-06-24 23:25:40
# 426851 -84.445400 2023-09-08 09:42:30
# 426852 -84.411811 2024-03-23 21:12:46
#
# [426853 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'type', 'paint_color', 'image_url',
#        'description', 'state', 'lat', 'long', 'posting_date'],
#       dtype='object')

# %%
unique_cars = df[['manufacturer', 'model']].drop_duplicates().reset_index(drop=True)
unique_cars['car_id'] = range(1, len(unique_cars) + 1)

cars_table = df[["id", "manufacturer", "model", "drive", "cylinders", "transmission", "paint_color"]]

cars_table = cars_table.merge(unique_cars, on=['manufacturer', 'model'], how='left').drop_duplicates().reset_index(drop=True)

cars_table
# Out:
#                 id manufacturer                     model drive  cylinders  \
# 0       7316814884          gmc  sierra 1500 crew cab slt   4wd          8
# 1       7316814758    chevrolet            silverado 1500   fwd          8
# 2       7316814989    chevrolet       silverado 1500 crew   rwd          8
# 3       7316743432       toyota      tundra double cab sr   fwd          8
# 4       7316356412         ford                 f-150 xlt   rwd          6
# ...            ...          ...                       ...   ...        ...
# 426848  7301591192       nissan         maxima s sedan 4d   fwd          6
# 426849  7301591187        volvo  s60 t5 momentum sedan 4d   fwd          6
# 426850  7301591147     cadillac          xt4 sport suv 4d   fwd          6
# 426851  7301591140        lexus           es 350 sedan 4d   fwd          6
# 426852  7301591129          bmw  4 series 430i gran coupe   rwd          6
#
#        transmission paint_color  car_id
# 0         automatic       white       1
# 1         automatic        blue       2
# 2         automatic         red       3
# 3         automatic         red       4
# 4         automatic       black       5
# ...             ...         ...     ...
# 426848    automatic        blue    1099
# 426849    automatic         red      56
# 426850    automatic       white      28
# 426851    automatic      silver    1289
# 426852    automatic      silver    4897
#
# [426853 rows x 8 columns]

# %%
cars_table[(cars_table['manufacturer'] == 'volvo') & (cars_table['model'] == 's60 t5 momentum sedan 4d')]
# Out:
#                 id manufacturer                     model drive  cylinders  \
# 62      7310308166        volvo  s60 t5 momentum sedan 4d   fwd          6
# 63      7310276274        volvo  s60 t5 momentum sedan 4d   fwd          6
# 1941    7310344611        volvo  s60 t5 momentum sedan 4d   fwd          8
# 1942    7310319913        volvo  s60 t5 momentum sedan 4d   fwd          6
# 21142   7301594863        volvo  s60 t5 momentum sedan 4d   fwd          6
# 28748   7306238668        volvo  s60 t5 momentum sedan 4d   fwd          8
# 69530   7310350865        volvo  s60 t5 momentum sedan 4d   fwd          4
# 72404   7302668967        volvo  s60 t5 momentum sedan 4d   fwd          8
# 74290   7309400415        volvo  s60 t5 momentum sedan 4d   fwd          4
# 79663   7309250358        volvo  s60 t5 momentum sedan 4d   fwd          4
# 79667   7309223129        volvo  s60 t5 momentum sedan 4d   fwd          6
# 83427   7301609079        volvo  s60 t5 momentum sedan 4d   fwd          8
# 97416   7306192008        volvo  s60 t5 momentum sedan 4d   fwd          4
# 127129  7310357800        volvo  s60 t5 momentum sedan 4d   fwd          8
# 127163  7306136487        volvo  s60 t5 momentum sedan 4d   fwd          4
# 127465  7301598981        volvo  s60 t5 momentum sedan 4d   fwd          8
# 139606  7301627218        volvo  s60 t5 momentum sedan 4d   fwd          8
# 143103  7301597979        volvo  s60 t5 momentum sedan 4d   fwd          4
# 154259  7307175822        volvo  s60 t5 momentum sedan 4d   fwd          4
# 160030  7301601179        volvo  s60 t5 momentum sedan 4d   fwd          6
# 170504  7310326014        volvo  s60 t5 momentum sedan 4d   fwd          8
# 170887  7307142364        volvo  s60 t5 momentum sedan 4d   4wd          4
# 174207  7307158852        volvo  s60 t5 momentum sedan 4d   4wd          4
# 175276  7309124539        volvo  s60 t5 momentum sedan 4d   fwd          6
# 175511  7309124534        volvo  s60 t5 momentum sedan 4d   fwd          6
# 175694  7309124453        volvo  s60 t5 momentum sedan 4d   fwd          8
# 195305  7301636839        volvo  s60 t5 momentum sedan 4d   fwd          4
# 195765  7301673707        volvo  s60 t5 momentum sedan 4d   fwd          6
# 203488  7301682021        volvo  s60 t5 momentum sedan 4d   fwd          4
# 207519  7301650586        volvo  s60 t5 momentum sedan 4d   fwd          4
# 208404  7307164217        volvo  s60 t5 momentum sedan 4d   fwd          8
# 208407  7307112400        volvo  s60 t5 momentum sedan 4d   fwd          4
# 209840  7301661506        volvo  s60 t5 momentum sedan 4d   fwd          4
# 210129  7301594891        volvo  s60 t5 momentum sedan 4d   fwd          6
# 216899  7310338480        volvo  s60 t5 momentum sedan 4d   fwd          8
# 217016  7306192054        volvo  s60 t5 momentum sedan 4d   fwd          6
# 220929  7301595552        volvo  s60 t5 momentum sedan 4d   fwd          4
# 231562  7301629996        volvo  s60 t5 momentum sedan 4d   fwd          4
# 243798  7306301860        volvo  s60 t5 momentum sedan 4d   fwd          6
# 255975  7310344933        volvo  s60 t5 momentum sedan 4d   fwd          6
# 260180  7314588747        volvo  s60 t5 momentum sedan 4d   fwd          6
# 262558  7301955497        volvo  s60 t5 momentum sedan 4d   fwd          4
# 288621  7307212755        volvo  s60 t5 momentum sedan 4d   fwd          8
# 288623  7307153795        volvo  s60 t5 momentum sedan 4d   rwd          4
# 302919  7307194382        volvo  s60 t5 momentum sedan 4d   fwd          4
# 302922  7307109759        volvo  s60 t5 momentum sedan 4d   fwd          4
# 332335  7307101619        volvo  s60 t5 momentum sedan 4d   fwd          6
# 332336  7307101531        volvo  s60 t5 momentum sedan 4d   4wd          6
# 349116  7310308350        volvo  s60 t5 momentum sedan 4d   fwd          6
# 349150  7306148062        volvo  s60 t5 momentum sedan 4d   fwd          4
# 353804  7310314031        volvo  s60 t5 momentum sedan 4d   fwd          8
# 353907  7306185224        volvo  s60 t5 momentum sedan 4d   fwd          4
# 364618  7314675563        volvo  s60 t5 momentum sedan 4d   fwd          4
# 366662  7301630013        volvo  s60 t5 momentum sedan 4d   fwd          4
# 426849  7301591187        volvo  s60 t5 momentum sedan 4d   fwd          6
#
#        transmission paint_color  car_id
# 62        automatic      silver      56
# 63        automatic       black      56
# 1941      automatic       black      56
# 1942      automatic       black      56
# 21142     automatic         red      56
# 28748     automatic       black      56
# 69530     automatic       black      56
# 72404     automatic         red      56
# 74290     automatic         red      56
# 79663     automatic       white      56
# 79667     automatic       black      56
# 83427     automatic         red      56
# 97416     automatic       black      56
# 127129    automatic       white      56
# 127163    automatic       black      56
# 127465    automatic         red      56
# 139606    automatic         red      56
# 143103    automatic         red      56
# 154259    automatic       white      56
# 160030    automatic         red      56
# 170504    automatic      silver      56
# 170887    automatic       white      56
# 174207    automatic       white      56
# 175276    automatic        blue      56
# 175511    automatic      silver      56
# 175694    automatic       green      56
# 195305    automatic         red      56
# 195765    automatic         red      56
# 203488    automatic         red      56
# 207519    automatic         red      56
# 208404    automatic       black      56
# 208407    automatic         red      56
# 209840    automatic         red      56
# 210129    automatic         red      56
# 216899    automatic       white      56
# 217016    automatic       black      56
# 220929    automatic         red      56
# 231562    automatic         red      56
# 243798    automatic         red      56
# 255975    automatic       black      56
# 260180    automatic       black      56
# 262558    automatic         red      56
# 288621    automatic       black      56
# 288623    automatic       white      56
# 302919    automatic       black      56
# 302922    automatic       white      56
# 332335    automatic       black      56
# 332336    automatic       white      56
# 349116    automatic       white      56
# 349150    automatic       black      56
# 353804    automatic      silver      56
# 353907    automatic       black      56
# 364618    automatic       black      56
# 366662    automatic         red      56
# 426849    automatic         red      56

# %%
colors = df["paint_color"].dropna().unique()
colors_table = pd.DataFrame(colors, columns=["color"])

hex_dict = {
    'black': '#000000',
    'blue': '#0000FF',
    'brown': '#A52A2A',
    'green': '#008000',
    'grey': '#808080',
    'orange': '#FFA500',
    'purple': '#800080',
    'red': '#FF0000',
    'silver': '#C0C0C0',
    'white': '#FFFFFF',
    'yellow': '#FFFF00',
}

colors_table['hex'] = colors_table['color'].map(hex_dict)

colors_table
# Out:
#      color      hex
# 0    white  #FFFFFF
# 1     blue  #0000FF
# 2      red  #FF0000
# 3    black  #000000
# 4   silver  #C0C0C0
# 5     grey  #808080
# 6    brown  #A52A2A
# 7    green  #008000
# 8   yellow  #FFFF00
# 9   orange  #FFA500
# 10  purple  #800080

# %%
fake = Faker()

num_users = 500

user_data = {
    'user_id': random.sample(range(10000000, 100000000), num_users), # 8 digit user_id
    'first_name': [fake.first_name() for _ in range(num_users)],
    'last_name': [fake.last_name() for _ in range(num_users)],
    'email': [fake.email() for _ in range(num_users)],
    'date_of_birth': [fake.date_of_birth(minimum_age=18, maximum_age=90) for _ in range(num_users)],
    'password': [fake.password(length=10, special_chars=True, digits=True, upper_case=True, lower_case=True) for _ in range(num_users)]
}

users_table = pd.DataFrame(user_data)
users_table
# Out:
#       user_id first_name  last_name                          email  \
# 0    27212364   Brittany     Murphy            maria76@example.net
# 1    32317483    Brandon      Ayala              vpace@example.com
# 2    34518768  Alexandra     Parker       jacqueline86@example.net
# 3    73347600    Jessica   Sandoval           mgardner@example.org
# 4    19650163     Latoya       Neal    cooperstephanie@example.net
# ..        ...        ...        ...                            ...
# 495  31874198    William     Thomas  robertsonjeremiah@example.org
# 496  75466571       Adam      Gibbs       brandonjones@example.com
# 497  69531356     Kristy       Gray     victoranderson@example.org
# 498  56385499      Karen   Williams         jonathan29@example.net
# 499  21437909   Jennifer  Fernandez             jsalas@example.org
#
#     date_of_birth    password
# 0      1984-09-15  %QSqQ5nq(7
# 1      1969-11-14  O!9O4qF8(I
# 2      1951-09-05  r238YEmZ*W
# 3      1961-01-05  w#z4NzZm3+
# 4      1941-12-07  VolIKelE^3
# ..            ...         ...
# 495    1956-06-09  %gP3NJWz%L
# 496    1945-04-18  k3iPkqpe_5
# 497    1992-07-28  C0KzPRlV+(
# 498    1949-07-15  aIj87hwiE*
# 499    2002-03-13  $fgVYtk660
#
# [500 rows x 6 columns]

# %%
listings_table = df[["id", "url", "region", "image_url", "description", "condition", "vin", "lat", "long", "state", "price", "posting_date"]]
listings_table["car_id"] = cars_table['car_id']

listings_table = listings_table.rename(columns={
    "url": "listing_url",
    "lat": "lat_id",
    "long": "long_id",
    "state": "state_id"
})

listings_table
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_40212\3592155776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_table["car_id"] = cars_table['car_id']
#                 id                                        listing_url  \
# 0       7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2       7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3       7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4       7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426848  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426849  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426850  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426851  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426852  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                                          image_url  \
# 0        auburn  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1        auburn  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2        auburn  https://images.craigslist.org/01212_jjirIWa0y0...
# 3        auburn  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4        auburn  https://images.craigslist.org/00404_l4loxHvdQe...
# ...         ...                                                ...
# 426848  wyoming  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426849  wyoming  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426850  wyoming  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426851  wyoming  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426852  wyoming  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description  condition  \
# 0       Carvana is the safer way to buy a car During t...       good
# 1       Carvana is the safer way to buy a car During t...       good
# 2       Carvana is the safer way to buy a car During t...       good
# 3       Carvana is the safer way to buy a car During t...       good
# 4       2013 F-150 XLT V6 4 Door. Good condition. Leve...  excellent
# ...                                                   ...        ...
# 426848  Carvana is the safer way to buy a car During t...       good
# 426849  Carvana is the safer way to buy a car During t...       good
# 426850  Carvana is the safer way to buy a car During t...       good
# 426851  Carvana is the safer way to buy a car During t...       good
# 426852  Carvana is the safer way to buy a car During t...       good
#
#                       vin     lat_id    long_id state_id       price  \
# 0       3GTP1VEC4EG551563  32.590000 -85.480000       al   89.331452
# 1       1GCSCSE06AZ123805  32.590000 -85.480000       al   60.077330
# 2       3GCPWCED5LG130317  32.590000 -85.480000       al  105.288246
# 3       5TFRM5F17HX120972  32.590000 -85.480000       al   82.416841
# 4       506XWT6HAFWG1BAT0  32.592000 -85.518900       al   39.891985
# ...                   ...        ...        ...      ...         ...
# 426848  1N4AA6AV6KC367801  33.786500 -84.445400       wy   62.736795
# 426849  7JR102FKXLG042696  33.786500 -84.445400       wy   81.353055
# 426850  1GYFZFR46LF088296  33.779214 -84.411811       wy   93.054704
# 426851  58ABK1GG4JU103853  33.786500 -84.445400       wy   77.097910
# 426852  WBA4J1C58KBM14708  33.779214 -84.411811       wy   81.353055
#
#               posting_date  car_id
# 0      2023-07-28 16:49:09       1
# 1      2024-04-02 13:25:13       2
# 2      2024-03-23 01:04:24       3
# 3      2024-04-02 12:42:57       4
# 4      2023-07-20 04:22:18       5
# ...                    ...     ...
# 426848 2024-04-22 13:43:38    1100
# 426849 2024-03-30 19:26:23      56
# 426850 2024-06-09 23:37:38      28
# 426851 2024-01-19 16:15:09    1292
# 426852 2024-01-29 18:28:51    4892
#
# [426853 rows x 13 columns]

# %%
import pandas as pd

state_data = {
    'state_id': ['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
                   'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'ma',
                   'mi', 'mn', 'ms', 'mo', 'mt', 'nc', 'ne', 'nv', 'nj', 'nm', 'ny',
                   'nh', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
                   'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'],
    'state_name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 
                   'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 
                   'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 
                   'Montana', 'North Carolina', 'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'New Hampshire', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
                   'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'time_zone': ['Central', 'Alaska', 'Mountain', 'Central', 'Pacific', 'Mountain', 'Eastern', 'Eastern', 'Eastern', 'Eastern', 
                  'Eastern', 'Hawaii-Aleutian', 'Mountain', 'Central', 'Eastern', 'Central', 'Central', 'Eastern', 'Central', 
                  'Eastern', 'Eastern', 'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Central', 
                  'Pacific', 'Eastern', 'Mountain', 'Eastern', 'Eastern', 'Central', 'Eastern', 'Central', 'Pacific', 'Eastern', 
                  'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Eastern', 'Pacific', 'Eastern', 
                  'Central', 'Mountain']
}

states_table = pd.DataFrame(state_data)
states_table
# Out:
#    state_id            state_name        time_zone
# 0        al               Alabama          Central
# 1        ak                Alaska           Alaska
# 2        az               Arizona         Mountain
# 3        ar              Arkansas          Central
# 4        ca            California          Pacific
# 5        co              Colorado         Mountain
# 6        ct           Connecticut          Eastern
# 7        dc  District of Columbia          Eastern
# 8        de              Delaware          Eastern
# 9        fl               Florida          Eastern
# 10       ga               Georgia          Eastern
# 11       hi                Hawaii  Hawaii-Aleutian
# 12       id                 Idaho         Mountain
# 13       il              Illinois          Central
# 14       in               Indiana          Eastern
# 15       ia                  Iowa          Central
# 16       ks                Kansas          Central
# 17       ky              Kentucky          Eastern
# 18       la             Louisiana          Central
# 19       me                 Maine          Eastern
# 20       md              Maryland          Eastern
# 21       ma         Massachusetts          Eastern
# 22       mi              Michigan          Eastern
# 23       mn             Minnesota          Central
# 24       ms           Mississippi          Central
# 25       mo              Missouri          Central
# 26       mt               Montana         Mountain
# 27       nc        North Carolina          Eastern
# 28       ne              Nebraska          Central
# 29       nv                Nevada          Pacific
# 30       nj            New Jersey          Eastern
# 31       nm            New Mexico         Mountain
# 32       ny              New York          Eastern
# 33       nh         New Hampshire          Eastern
# 34       nd          North Dakota          Central
# 35       oh                  Ohio          Eastern
# 36       ok              Oklahoma          Central
# 37       or                Oregon          Pacific
# 38       pa          Pennsylvania          Eastern
# 39       ri          Rhode Island          Eastern
# 40       sc        South Carolina          Eastern
# 41       sd          South Dakota          Central
# 42       tn             Tennessee          Central
# 43       tx                 Texas          Central
# 44       ut                  Utah         Mountain
# 45       vt               Vermont          Eastern
# 46       va              Virginia          Eastern
# 47       wa            Washington          Pacific
# 48       wv         West Virginia          Eastern
# 49       wi             Wisconsin          Central
# 50       wy               Wyoming         Mountain

# %%
num_favorites = 750
favorite_data = {
    'id': [random.choice(cars_table['id']) for _ in range(num_favorites)],
    'user_id': [random.choice(users_table['user_id']) for _ in range(num_favorites)]
}

favorites_table = pd.DataFrame(favorite_data)
favorites_table['car_id'] = favorites_table['id'].map(cars_table.set_index('id')['car_id'].to_dict())

favorites_table
# Out:
#              id   user_id  car_id
# 0    7310314165  68558566     566
# 1    7315137757  80476560     239
# 2    7316138479  30931024    2846
# 3    7302194328  14129170       2
# 4    7315167224  39118733    1304
# ..          ...       ...     ...
# 745  7309843508  31837777     656
# 746  7315676999  52395548     192
# 747  7314837762  40218374      33
# 748  7315150201  34887668     295
# 749  7302312628  58129910    5697
#
# [750 rows x 3 columns]

# %%
# # save da files
# cars_table.to_csv('cars_table.csv', index=False)
# colors_table.to_csv('colors_table.csv', index=False)
# users_table.to_csv('users_table.csv', index=False)
# rentals_table.to_csv('rentals_table.csv', index=False)
# listings_table.to_csv('listings_table.csv', index=False)
# favorites_table.to_csv('favorites_table.csv', index=False)
# states_table.to_csv('states_table.csv', index=False)

# %% [markdown]
# # Sample Dataset

# %%
sample_df = df.sample(n=20).reset_index(drop=True)
min_mileage = 5000
max_mileage = 200000
sample_df['mileage'] = [random.randint(min_mileage, max_mileage) for _ in range(len(sample_df))]

sample_df
# Out:
#             id                                                url  \
# 0   7310842213  https://raleigh.craigslist.org/ctd/d/raleigh-2...
# 1   7308268142  https://savannah.craigslist.org/ctd/d/savannah...
# 2   7316671476  https://chattanooga.craigslist.org/ctd/d/chatt...
# 3   7312960878  https://wausau.craigslist.org/ctd/d/merrill-20...
# 4   7313394387  https://fortmyers.craigslist.org/col/ctd/d/nap...
# 5   7314618037  https://omaha.craigslist.org/ctd/d/higginsvill...
# 6   7315807724  https://sandiego.craigslist.org/csd/cto/d/del-...
# 7   7316764465  https://missoula.craigslist.org/ctd/d/coeur-al...
# 8   7311550702  https://ventura.craigslist.org/cto/d/ventura-w...
# 9   7316951646  https://youngstown.craigslist.org/ctd/d/youngs...
# 10  7313340076  https://philadelphia.craigslist.org/cto/d/nort...
# 11  7308050880  https://fortcollins.craigslist.org/ctd/d/evans...
# 12  7313086119  https://sanantonio.craigslist.org/ctd/d/san-an...
# 13  7303734519  https://norfolk.craigslist.org/ctd/d/norfolk-2...
# 14  7308683920  https://sarasota.craigslist.org/ctd/d/bradento...
# 15  7303295709  https://pueblo.craigslist.org/ctd/d/penrose-20...
# 16  7313273600  https://boston.craigslist.org/sob/ctd/d/brockt...
# 17  7314936270  https://scranton.craigslist.org/ctd/d/lake-ari...
# 18  7311883855  https://allentown.craigslist.org/ctd/d/easton-...
# 19  7303236346  https://allentown.craigslist.org/ctd/d/easton-...
#
#                      region                           region_url       price  \
# 0     raleigh / durham / CH       https://raleigh.craigslist.org  101.033101
# 1     savannah / hinesville      https://savannah.craigslist.org   90.395238
# 2               chattanooga   https://chattanooga.craigslist.org  105.288246
# 3                    wausau        https://wausau.craigslist.org   13.284031
# 4     ft myers / SW florida     https://fortmyers.craigslist.org   65.396261
# 5    omaha / council bluffs         https://omaha.craigslist.org  148.876889
# 6                 san diego      https://sandiego.craigslist.org   74.199092
# 7                  missoula      https://missoula.craigslist.org   77.119186
# 8            ventura county       https://ventura.craigslist.org    0.000000
# 9                youngstown    https://youngstown.craigslist.org   21.262428
# 10             philadelphia  https://philadelphia.craigslist.org   62.497443
# 11  fort collins / north CO   https://fortcollins.craigslist.org   48.109734
# 12              san antonio    https://sanantonio.craigslist.org   25.262264
# 13  norfolk / hampton roads       https://norfolk.craigslist.org   17.392906
# 14       sarasota-bradenton      https://sarasota.craigslist.org   21.243812
# 15                   pueblo        https://pueblo.craigslist.org   72.808192
# 16                   boston        https://boston.craigslist.org    7.978397
# 17  scranton / wilkes-barre      https://scranton.craigslist.org    7.167260
# 18            lehigh valley     https://allentown.craigslist.org   86.671987
# 19            lehigh valley     https://allentown.craigslist.org   90.395238
#
#       year   manufacturer                         model  condition  cylinders  \
# 0   2019.0            bmw    x3 xdrive30i sport utility       good          6
# 1   2018.0           jeep     wrangler unlimited willys       good          6
# 2   2020.0      chevrolet           silverado 1500 crew       good          8
# 3   2007.0        mercury                 milan premier       good          4
# 4   2013.0            gmc  sierra 1500 extended cab slt       good          8
# 5   2018.0      chevrolet              silverado 2500hd       good          8
# 6   2018.0  mercedes-benz                    benz c350e  excellent          4
# 7   2019.0     volkswagen                     tiguan se       good          4
# 8   2000.0           jeep                      wrangler  excellent          8
# 9   2015.0         subaru         legacy awd 4dr. sedan  excellent          4
# 10  2019.0         nissan                       leaf sl  excellent          8
# 11  2015.0       infiniti                  qx50 journey       good          6
# 12  2015.0         toyota                    corolla le   like new          4
# 13  2008.0         toyota                         camry  excellent          8
# 14  2003.0           ford                         f-150       good          6
# 15  2016.0           ford                    expedition  excellent          8
# 16  2008.0      chevrolet            international 4300  excellent          8
# 17  2002.0      chevrolet                      cavalier  excellent          8
# 18  2009.0      chevrolet             corvette coupe 2d       good          8
# 19  2014.0            gmc    sierra 1500 double cab slt       good          8
#
#     ... drive       type paint_color  \
# 0   ...   rwd        SUV       black
# 1   ...   4wd      other       white
# 2   ...   fwd     pickup         red
# 3   ...   4wd      other       black
# 4   ...   4wd     pickup       white
# 5   ...   4wd      sedan      silver
# 6   ...   rwd      sedan       black
# 7   ...   4wd        SUV        blue
# 8   ...   4wd     pickup       white
# 9   ...   4wd      sedan        blue
# 10  ...   fwd  hatchback       black
# 11  ...   fwd        SUV       black
# 12  ...   fwd      sedan        blue
# 13  ...   fwd      sedan       black
# 14  ...   rwd     pickup       green
# 15  ...   fwd     pickup       black
# 16  ...   4wd        SUV       black
# 17  ...   4wd      coupe        blue
# 18  ...   rwd      coupe      silver
# 19  ...   4wd     pickup       white
#
#                                             image_url  \
# 0   https://images.craigslist.org/00o0o_70u670pbXw...
# 1   https://images.craigslist.org/00d0d_lQWs0jxSyo...
# 2   https://images.craigslist.org/01212_jjirIWa0y0...
# 3   https://images.craigslist.org/00V0V_fBjNmz6eAa...
# 4   https://images.craigslist.org/00404_kyhHnNhxLm...
# 5   https://images.craigslist.org/00G0G_LtoktvJ5ve...
# 6   https://images.craigslist.org/00Q0Q_l0rMAT8VuE...
# 7   https://images.craigslist.org/00D0D_jwdKD9QnGY...
# 8   https://images.craigslist.org/01515_bXHzE3XHWN...
# 9   https://images.craigslist.org/00202_2MfZlrVxlI...
# 10  https://images.craigslist.org/00k0k_61qJaTTTZB...
# 11  https://images.craigslist.org/00606_fHCyGbLGad...
# 12  https://images.craigslist.org/00X0X_j8httQlIX5...
# 13  https://images.craigslist.org/00g0g_eUgxzHwbzd...
# 14  https://images.craigslist.org/00G0G_kHEyR4sGbd...
# 15  https://images.craigslist.org/00e0e_cevFOSDHzx...
# 16  https://images.craigslist.org/00u0u_lq9uHG6qIA...
# 17  https://images.craigslist.org/00M0M_dpY92BRgWU...
# 18  https://images.craigslist.org/01414_8SIP72Awg9...
# 19  https://images.craigslist.org/00o0o_bdqhJoRW4x...
#
#                                           description state        lat  \
# 0   Practice of you how argue nature sing. Staff u...    nc  35.820000
# 1   Her generation effect two home. Way should voi...    ga  32.080000
# 2   After some work material industry idea season....    tn  35.060000
# 3   It realize plan meeting leg.\nAbility customer...    wi  45.192647
# 4   Answer size husband least forget. Because toge...    fl  26.140000
# 5   Water five law. Like cultural laugh member. Ci...    ia  39.070500
# 6   Under serious hotel state my scientist. Decade...    ca  32.955500
# 7   Executive foot quickly system me return. Hit a...    mt  47.696062
# 8   Offer they good loss. All girl social necessar...    ca  34.278800
# 9   Wait student become manager interest. Choice s...    oh  41.025200
# 10  On good five leg drive. Enjoy would skin popul...    pa  40.216600
# 11  Race maintain activity own door article citize...    co  40.394420
# 12  Third cut maybe fall mind serious sea. Low eye...    tx  29.533400
# 13  Rate whether behavior development surface. Tre...    va  36.869810
# 14  Specific teacher quality president key like. W...    fl  27.473591
# 15  Argue than a major accept let it. Central rese...    co  38.421570
# 16  Through issue its beyond tough. Quite organiza...    ma  42.061319
# 17  Top than today bank economic lose. Party indic...    pa  41.407030
# 18  Term history move mind cost sign especially. A...    pa  40.680000
# 19  Top third claim appear. Quickly just firm what...    pa  40.680000
#
#           long        posting_date mileage
# 0   -78.650000 2023-08-20 18:45:44   66319
# 1   -81.100000 2024-05-24 12:59:44  109615
# 2   -85.250000 2023-10-05 02:45:06  136008
# 3   -89.665496 2023-11-18 05:51:49   39262
# 4   -81.790000 2024-04-22 19:28:59   20636
# 5   -93.713300 2023-11-14 18:45:23  114191
# 6  -117.225200 2023-12-04 18:52:53  175294
# 7  -116.781406 2024-01-08 11:19:59   58533
# 8  -119.165100 2023-09-09 15:13:22   29469
# 9   -80.668700 2023-08-13 21:49:28   99449
# 10  -75.256500 2023-08-17 18:30:09  121764
# 11 -104.736165 2024-03-15 00:10:42  104744
# 12  -98.497500 2023-10-10 04:54:57   75082
# 13  -76.225020 2024-05-17 11:27:28   67649
# 14  -82.570679 2024-06-11 12:54:06  109504
# 15 -105.049668 2024-03-19 04:39:36   84771
# 16  -71.013413 2024-03-25 08:42:46  143569
# 17  -75.439130 2023-08-08 19:32:47  167827
# 18  -75.220000 2024-03-03 04:53:36   68995
# 19  -75.220000 2023-10-03 11:53:55  106054
#
# [20 rows x 25 columns]

# %%
unique_cars = sample_df[['manufacturer', 'model']].drop_duplicates().reset_index(drop=True)

sample_cars_table = sample_df[["manufacturer", "model", "drive", "cylinders", "transmission", "fuel"]]
sample_cars_table['drive'] = sample_cars_table['drive'].replace('other', 'gas')

# drop duplicates
sample_cars_table = sample_cars_table.drop_duplicates(subset=['manufacturer', 'model']).reset_index(drop=True)

sample_cars_table
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_37740\571989658.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_cars_table['drive'] = sample_cars_table['drive'].replace('other', 'gas')
#      manufacturer                         model drive  cylinders transmission  \
# 0             bmw    x3 xdrive30i sport utility   rwd          6    automatic
# 1            jeep     wrangler unlimited willys   4wd          6    automatic
# 2       chevrolet           silverado 1500 crew   fwd          8    automatic
# 3         mercury                 milan premier   4wd          4    automatic
# 4             gmc  sierra 1500 extended cab slt   4wd          8    automatic
# 5       chevrolet              silverado 2500hd   4wd          8    automatic
# 6   mercedes-benz                    benz c350e   rwd          4    automatic
# 7      volkswagen                     tiguan se   4wd          4       manual
# 8            jeep                      wrangler   4wd          8       manual
# 9          subaru         legacy awd 4dr. sedan   4wd          4    automatic
# 10         nissan                       leaf sl   fwd          8    automatic
# 11       infiniti                  qx50 journey   fwd          6    automatic
# 12         toyota                    corolla le   fwd          4    automatic
# 13         toyota                         camry   fwd          8    automatic
# 14           ford                         f-150   rwd          6    automatic
# 15           ford                    expedition   fwd          8    automatic
# 16      chevrolet            international 4300   4wd          8    automatic
# 17      chevrolet                      cavalier   4wd          8    automatic
# 18      chevrolet             corvette coupe 2d   rwd          8    automatic
# 19            gmc    sierra 1500 double cab slt   4wd          8    automatic
#
#         fuel
# 0        gas
# 1        gas
# 2        gas
# 3        gas
# 4      other
# 5     diesel
# 6     hybrid
# 7        gas
# 8        gas
# 9        gas
# 10  electric
# 11     other
# 12       gas
# 13       gas
# 14       gas
# 15       gas
# 16    diesel
# 17       gas
# 18       gas
# 19       gas

# %%
num_users = 10

user_data = {
    'user_id': [str(uuid.uuid4())[:8] for _ in range(num_users)],
    'first_name': [fake.first_name() for _ in range(num_users)],
    'last_name': [fake.last_name() for _ in range(num_users)],
    'email': [fake.email() for _ in range(num_users)],
    'date_of_birth': [fake.date_of_birth(minimum_age=18, maximum_age=60) for _ in range(num_users)],
    'password': [fake.password(length=10, special_chars=True, digits=True, upper_case=True, lower_case=True) for _ in range(num_users)]
}


sample_users_table = pd.DataFrame(user_data)

sample_users_table
# Out:
#     user_id first_name   last_name                         email  \
# 0  50d4e3b2     Xavier        Ward           sarah39@example.com
# 1  76397991     Amanda    Peterson  hamptonchristine@example.net
# 2  346050b0     Joshua      Mosley           keith78@example.org
# 3  04bc9af6     Nicole  Hutchinson        jonathon87@example.org
# 4  6eb4d8fb     Robert       Price             osoto@example.org
# 5  32b272f2    Melissa     Trevino           robin71@example.net
# 6  f97c209b    Richard    Martinez       gregorygene@example.net
# 7  90104220      Eddie       Smith       riveradanny@example.org
# 8  b1b071b2    Matthew      Mathis      thomasrobert@example.org
# 9  25d1cb2b      Tyler      Taylor            callen@example.net
#
#   date_of_birth    password
# 0    1983-02-16  *0(Fa5ncW6
# 1    1994-10-25  (U2gZrEwr!
# 2    1993-10-12  f4C6H36z+I
# 3    1992-07-11  Dc(_8kPx@_
# 4    1997-01-11  U&7@SDfXTH
# 5    1985-03-16  Pj0Bb#^w%k
# 6    1992-03-24  %f$onUMtM5
# 7    1985-06-20  %ye!DHef48
# 8    1986-12-19  3(hRaoj#!i
# 9    1972-10-01  taaIv+96+4

# %%
fake = Faker()

num_owners = 10

owner_data = {
    'user_id': [str(uuid.uuid4())[:8] for _ in range(num_owners)],
    'first_name': [fake.first_name() for _ in range(num_owners)],
    'last_name': [fake.last_name() for _ in range(num_owners)],
    'email': [fake.email() for _ in range(num_owners)],
    'date_of_birth': [fake.date_of_birth(minimum_age=18, maximum_age=60) for _ in range(num_owners)],
    'password': [fake.password(length=10, special_chars=True, digits=True, upper_case=True, lower_case=True) for _ in range(num_owners)],
    'status': [random.choice(['active', 'inactive', 'banned']) for _ in range(num_owners)],
    'dealer_rating': [random.randint(1, 5) for _ in range(num_owners)],
    'dealer_num_ratings': [random.randint(1, 1000) for _ in range(num_owners)]
}

sample_owners_table = pd.DataFrame(owner_data)
sample_owners_table
# Out:
#     user_id first_name   last_name                        email date_of_birth  \
# 0  8ca4cbeb     Steven   Mccormick       sawyereric@example.org    2002-02-21
# 1  b78c5eed     Bailey      Gordon        lwilliams@example.net    1964-03-31
# 2  96a93939      Jacob        Boyd          etucker@example.com    2001-11-23
# 3  b00d4bc2      Molly     Walters        shannon91@example.com    1970-03-26
# 4  614ae04f      Emily       Smith      sandradavis@example.net    1986-11-12
# 5  e9a297d7     Monica       Lewis       jennifer64@example.org    1986-08-23
# 6  1f9f9c10        Amy       Logan            kwood@example.org    2003-05-20
# 7  82c4c3bf       Rita      Weaver  robleskatherine@example.org    1968-11-07
# 8  2d2a66b0       Eric  Valenzuela     pottspatrick@example.com    1991-10-26
# 9  b1f64ad0      Kevin      Knight     bradleyjones@example.org    1989-08-25
#
#      password    status  dealer_rating  dealer_num_ratings
# 0  %z3BRHtrC7    active              1                 754
# 1  )PW*TktXA2  inactive              3                 230
# 2  L9a37V6y#J    active              2                 708
# 3  Z9tLiAw1@9    active              3                 233
# 4  +N@3uzVxl1    active              4                 421
# 5  O)8^Q*wAde    active              5                  78
# 6  0wq9BILw#3  inactive              3                 328
# 7  @RHKV#NoD7    banned              2                 572
# 8  $rPTn^ZMq3  inactive              2                 393
# 9  adJVJrWn^9    active              4                 557

# %%
sample_listings_table = sample_df[["id", "manufacturer", "model", "region", "image_url", "description", "condition", "state", "posting_date", "mileage"]]
sample_listings_table = sample_listings_table.rename(columns={
    "id": "listing_id",
    "state": "state_id"
})


sample_listings_table['status'] = [random.choice(['active', 'inactive']) for _ in range(len(sample_listings_table))]
sample_listings_table['price'] = [random.uniform(1, 60) for _ in range(len(sample_listings_table))]
sample_listings_table['posting_date'] = pd.to_datetime(sample_listings_table['posting_date'], errors='coerce')
sample_listings_table['posting_date'] = sample_listings_table['posting_date'].apply(lambda x: x if x.year > 1900 else datetime.now())
sample_listings_table['owner_id'] = np.random.choice(sample_owners_table['user_id'], size=len(sample_listings_table))
sample_listings_table['rent_time'] = [random.randint(5, 30) for _ in range(len(sample_listings_table))]

sample_listings_table
# Out:
#     listing_id   manufacturer                         model  \
# 0   7310842213            bmw    x3 xdrive30i sport utility
# 1   7308268142           jeep     wrangler unlimited willys
# 2   7316671476      chevrolet           silverado 1500 crew
# 3   7312960878        mercury                 milan premier
# 4   7313394387            gmc  sierra 1500 extended cab slt
# 5   7314618037      chevrolet              silverado 2500hd
# 6   7315807724  mercedes-benz                    benz c350e
# 7   7316764465     volkswagen                     tiguan se
# 8   7311550702           jeep                      wrangler
# 9   7316951646         subaru         legacy awd 4dr. sedan
# 10  7313340076         nissan                       leaf sl
# 11  7308050880       infiniti                  qx50 journey
# 12  7313086119         toyota                    corolla le
# 13  7303734519         toyota                         camry
# 14  7308683920           ford                         f-150
# 15  7303295709           ford                    expedition
# 16  7313273600      chevrolet            international 4300
# 17  7314936270      chevrolet                      cavalier
# 18  7311883855      chevrolet             corvette coupe 2d
# 19  7303236346            gmc    sierra 1500 double cab slt
#
#                      region  \
# 0     raleigh / durham / CH
# 1     savannah / hinesville
# 2               chattanooga
# 3                    wausau
# 4     ft myers / SW florida
# 5    omaha / council bluffs
# 6                 san diego
# 7                  missoula
# 8            ventura county
# 9                youngstown
# 10             philadelphia
# 11  fort collins / north CO
# 12              san antonio
# 13  norfolk / hampton roads
# 14       sarasota-bradenton
# 15                   pueblo
# 16                   boston
# 17  scranton / wilkes-barre
# 18            lehigh valley
# 19            lehigh valley
#
#                                             image_url  \
# 0   https://images.craigslist.org/00o0o_70u670pbXw...
# 1   https://images.craigslist.org/00d0d_lQWs0jxSyo...
# 2   https://images.craigslist.org/01212_jjirIWa0y0...
# 3   https://images.craigslist.org/00V0V_fBjNmz6eAa...
# 4   https://images.craigslist.org/00404_kyhHnNhxLm...
# 5   https://images.craigslist.org/00G0G_LtoktvJ5ve...
# 6   https://images.craigslist.org/00Q0Q_l0rMAT8VuE...
# 7   https://images.craigslist.org/00D0D_jwdKD9QnGY...
# 8   https://images.craigslist.org/01515_bXHzE3XHWN...
# 9   https://images.craigslist.org/00202_2MfZlrVxlI...
# 10  https://images.craigslist.org/00k0k_61qJaTTTZB...
# 11  https://images.craigslist.org/00606_fHCyGbLGad...
# 12  https://images.craigslist.org/00X0X_j8httQlIX5...
# 13  https://images.craigslist.org/00g0g_eUgxzHwbzd...
# 14  https://images.craigslist.org/00G0G_kHEyR4sGbd...
# 15  https://images.craigslist.org/00e0e_cevFOSDHzx...
# 16  https://images.craigslist.org/00u0u_lq9uHG6qIA...
# 17  https://images.craigslist.org/00M0M_dpY92BRgWU...
# 18  https://images.craigslist.org/01414_8SIP72Awg9...
# 19  https://images.craigslist.org/00o0o_bdqhJoRW4x...
#
#                                           description  condition state_id  \
# 0   Practice of you how argue nature sing. Staff u...       good       nc
# 1   Her generation effect two home. Way should voi...       good       ga
# 2   After some work material industry idea season....       good       tn
# 3   It realize plan meeting leg.\nAbility customer...       good       wi
# 4   Answer size husband least forget. Because toge...       good       fl
# 5   Water five law. Like cultural laugh member. Ci...       good       ia
# 6   Under serious hotel state my scientist. Decade...  excellent       ca
# 7   Executive foot quickly system me return. Hit a...       good       mt
# 8   Offer they good loss. All girl social necessar...  excellent       ca
# 9   Wait student become manager interest. Choice s...  excellent       oh
# 10  On good five leg drive. Enjoy would skin popul...  excellent       pa
# 11  Race maintain activity own door article citize...       good       co
# 12  Third cut maybe fall mind serious sea. Low eye...   like new       tx
# 13  Rate whether behavior development surface. Tre...  excellent       va
# 14  Specific teacher quality president key like. W...       good       fl
# 15  Argue than a major accept let it. Central rese...  excellent       co
# 16  Through issue its beyond tough. Quite organiza...  excellent       ma
# 17  Top than today bank economic lose. Party indic...  excellent       pa
# 18  Term history move mind cost sign especially. A...       good       pa
# 19  Top third claim appear. Quickly just firm what...       good       pa
#
#           posting_date  mileage    status      price  owner_id  rent_time
# 0  2023-08-20 18:45:44    66319  inactive  15.730219  2d2a66b0         27
# 1  2024-05-24 12:59:44   109615  inactive  40.374408  b00d4bc2         22
# 2  2023-10-05 02:45:06   136008  inactive  50.279173  b1f64ad0         21
# 3  2023-11-18 05:51:49    39262  inactive  59.943741  e9a297d7         10
# 4  2024-04-22 19:28:59    20636    active  23.960843  e9a297d7         30
# 5  2023-11-14 18:45:23   114191  inactive  25.038366  b78c5eed         23
# 6  2023-12-04 18:52:53   175294  inactive  42.745320  96a93939         16
# 7  2024-01-08 11:19:59    58533  inactive  20.294453  2d2a66b0         24
# 8  2023-09-09 15:13:22    29469    active  51.406886  e9a297d7         26
# 9  2023-08-13 21:49:28    99449    active  47.440137  82c4c3bf         19
# 10 2023-08-17 18:30:09   121764  inactive  27.211483  8ca4cbeb         10
# 11 2024-03-15 00:10:42   104744  inactive   9.797176  82c4c3bf         30
# 12 2023-10-10 04:54:57    75082    active  29.887268  b1f64ad0         26
# 13 2024-05-17 11:27:28    67649  inactive  43.171212  82c4c3bf         12
# 14 2024-06-11 12:54:06   109504  inactive   9.457233  96a93939         23
# 15 2024-03-19 04:39:36    84771  inactive  55.491064  2d2a66b0         15
# 16 2024-03-25 08:42:46   143569  inactive  21.126697  e9a297d7         23
# 17 2023-08-08 19:32:47   167827  inactive  18.729008  1f9f9c10         17
# 18 2024-03-03 04:53:36    68995  inactive   7.370012  e9a297d7         15
# 19 2023-10-03 11:53:55   106054  inactive  57.949023  8ca4cbeb         15

# %%
num_reviews = 15

car_review_phrases = [
    "The car runs smoothly and has great mileage.",
    "I love the interior design and the comfort it offers.",
    "The engine performance is exceptional!",
    "Very reliable and fuel-efficient.",
    "The car looks stylish and is very easy to handle.",
    "I've had some issues with the transmission.",
    "The car is a bit overpriced for what it offers.",
    "Excellent customer service from the dealer.",
    "I had a great buying experience and the car is fantastic.",
    "The sound system in the car is top-notch.",
    "It's a decent car but lacks advanced features.",
    "Very spacious and comfortable for long drives.",
    "The air conditioning system works perfectly.",
    "I had to take it for repairs sooner than expected.",
    "The car offers a smooth and quiet ride.",
    "The handling is responsive and precise.",
    "The fuel economy could be better.",
    "Comfortable seating for long trips.",
    "The car's safety features are impressive.",
    "Great value for money.",
    "The exterior design is eye-catching.",
    "The dashboard layout is intuitive and user-friendly.",
    "Acceleration is swift and powerful.",
    "The car is perfect for city driving.",
    "The brakes are sensitive and reliable.",
    "The headlights provide excellent visibility.",
    "The suspension absorbs bumps well.",
    "The seats are supportive and adjustable.",
    "Road noise is minimal.",
    "The car's reliability rating is high.",
    "Cargo space is ample for groceries and luggage.",
    "The steering wheel feels comfortable in hand.",
    "The infotainment system is easy to use.",
    "The car handles well in all weather conditions.",
    "The paint quality is durable and glossy.",
    "The mileage per gallon is impressive.",
    "Maintenance costs are reasonable.",
    "The seats are heated and ventilated.",
    "The navigation system is accurate and responsive.",
    "The car has good resale value.",
    "I feel safe driving this car.",
    "The climate control system is effective.",
    "The rearview camera provides a clear view.",
    "The car accelerates smoothly from a stop.",
    "The gearbox shifts gears seamlessly.",
    "The suspension offers a comfortable ride.",
    "The cabin is quiet at highway speeds.",
    "The car's warranty coverage is comprehensive.",
    "The touchscreen interface is intuitive.",
    "The car handles curves with confidence.",
    "The interior materials are high-quality.",
    "The car's technology features are impressive.",
    "The seats have plenty of legroom.",
    "The steering is precise and responsive.",
    "The car's braking system is reliable.",
    "The adaptive cruise control works well.",
    "The car's design is timeless.",
    "The engine is powerful yet fuel-efficient.",
    "The car's Bluetooth connectivity is seamless.",
    "The dashboard displays essential information clearly.",
    "The sound quality of the audio system is excellent.",
    "The car has good visibility all around.",
    "The car's headlights illuminate the road well.",
    "The seats are easy to adjust for comfort.",
    "The car feels stable at high speeds.",
    "The steering is light and easy to maneuver.",
    "The car has plenty of storage compartments.",
    "The car's handling is agile and responsive.",
    "The seats provide excellent lumbar support.",
    "The car's resale value holds up well.",
    "The interior is spacious and well-designed.",
    "The car accelerates quickly when needed.",
    "The car's fuel tank is large for long trips.",
    "The car's exterior color is vibrant.",
    "The car's dashboard is well-organized.",
    "The car's entertainment system keeps passengers entertained.",
    "The car's suspension absorbs bumps smoothly.",
    "The car's cabin is insulated from road noise.",
    "The car's climate control keeps the cabin comfortable.",
    "The car's seats are plush and comfortable.",
    "The car's engine is quiet at idle.",
    "The car's transmission shifts gears seamlessly.",
    "The car's steering is precise and responsive.",
    "The car's brakes are strong and reliable.",
    "The car's fuel efficiency is impressive for its size.",
    "The car's safety features provide peace of mind.",
    "The car's infotainment system is intuitive to use.",
    "The car's interior design is modern and attractive.",
    "The car's exterior design is sporty and eye-catching.",
    "The car's ride quality is smooth and comfortable.",
    "The car's acceleration is brisk and powerful.",
    "The car's handling is nimble and agile.",
    "The car's suspension offers a balanced ride.",
    "The car's seats are supportive and ergonomic.",
    "The car's cabin is spacious and airy.",
    "The car's visibility is excellent from all angles.",
    "The car's technology features are cutting-edge.",
    "The car's fuel economy is efficient.",
    "The car's steering wheel feels solid and well-designed.",
    "The car's dashboard layout is logical and user-friendly.",
    "The car's rear seats are comfortable for passengers.",
    "The car's trunk space is generous for luggage.",
    "The car's exterior styling is elegant and refined.",
    "The car's interior materials are high-grade and durable.",
    "The car's ride is smooth and composed.",
    "The car's acceleration is strong and responsive.",
    "The car's handling is agile and precise.",
    "The car's brakes are powerful and reliable.",
    "The car's fuel efficiency is excellent.",
    "The car's safety features are advanced and effective.",
    "The car's infotainment system is intuitive and feature-rich.",
    "The car's interior design is stylish and modern.",
    "The car's exterior design is sleek and aerodynamic.",
    "The car's suspension absorbs bumps with ease.",
    "The car's seats are comfortable for long drives.",
    "The car's steering is light and responsive.",
    "The car's cabin is quiet at highway speeds.",
    "The car's visibility is clear and unobstructed.",
    "The car's technology enhances the driving experience.",
    "The car's climate control system is efficient and effective.",
    "The car's seats provide ample support and comfort.",
    "The car's audio system delivers crisp and clear sound.",
    "The car's interior is well-insulated from outside noise.",
    "The car's transmission shifts smoothly between gears.",
    "The car's exterior color is vibrant and attractive.",
    "The car's headlights provide excellent illumination.",
    "The car's touchscreen interface is user-friendly.",
    "The car's navigation system is accurate and reliable.",
    "The car's cargo space is ample for groceries and luggage.",
    "The car's steering response is precise and predictable.",
    "The car's suspension offers a smooth and controlled ride.",
    "The car's seats are plush and supportive.",
    "The car's cabin layout is practical and ergonomic.",
    "The car's exterior lines are sleek and modern.",
    "The car's engine delivers strong performance.",
    "The car's fuel economy is impressive for its class.",
    "The car's safety ratings are top-notch.",
    "The car's technology suite is comprehensive and intuitive.",
    "The car's interior materials are luxurious and refined.",
    "The car's exterior design is bold and distinctive.",
    "The car's ride quality is smooth and comfortable.",
    "The car's acceleration is brisk and exhilarating.",
    "The car's handling is precise and agile.",
    "The car's braking system is responsive and reliable.",
    "The car's fuel efficiency is excellent for its size.",
    "The car's safety features provide peace of mind.",
    "The car's infotainment system is easy to use.",
    "The car's interior design is elegant and sophisticated.",
    "The car's exterior styling is dynamic and attractive.",
    "The car's suspension absorbs bumps well.",
    "The car's cabin is spacious and comfortable.",
    "The car's steering is light and responsive.",
    "The car's visibility is excellent from all angles.",
    "The car's technology features are user-friendly.",
    "The car's fuel economy is efficient.",
    "The car's steering wheel feels comfortable in hand.",
    "The car's dashboard layout is intuitive and clear.",
    "The car's rear seats offer ample legroom.",
    "The car's trunk provides generous cargo space.",
    "The car's exterior finish is durable and glossy.",
    "The car's ride is smooth and composed.",
    "The car's acceleration is brisk and powerful.",
    "The car's handling is precise and nimble.",
    "The car's brakes are strong and responsive.",
    "The car's fuel efficiency is impressive for its class.",
    "The car's safety features are advanced and effective.",
    "The car's infotainment system is intuitive and responsive.",
    "The car's interior design is modern and attractive.",
    "The car's exterior design is sporty and eye-catching.",
    "The car's suspension provides a comfortable ride.",
    "The car's seats are supportive and comfortable.",
    "The car's cabin is spacious and well-appointed.",
    "The car's visibility is excellent from the driver's seat.",
    "The car's technology features enhance convenience and safety.",
    "The car's climate control system maintains a comfortable cabin temperature.",
    "The car's seats are ergonomically designed for long trips.",
    "The car's audio system delivers immersive sound quality.",
    "The car's interior is insulated from external noise.",
    "The car's transmission shifts seamlessly through gears.",
    "The car's exterior color is vibrant and eye-catching.",
    "The car's headlights illuminate the road ahead effectively.",
    "The car's touchscreen interface is intuitive to navigate."
]

def generate_car_review():
    phrase = random.choice(car_review_phrases)
    additional_comment = fake.sentence()
    return f"{phrase} {additional_comment}"

review_data = {
    'review_id': [str(uuid.uuid4())[:8] for _ in range(num_reviews)],
    'author': [random.choice(sample_users_table['user_id']) for _ in range(num_reviews)],  # FK to users table
    'listing_id': [random.choice(sample_listings_table['listing_id']) for _ in range(num_reviews)],  # FK to listings table
    'rating': [random.randint(1, 5) for _ in range(num_reviews)],
    'comments': [generate_car_review() for _ in range(num_reviews)]
}

sample_reviews_table = pd.DataFrame(review_data)
sample_reviews_table
# Out:
#    review_id    author  listing_id  rating  \
# 0   b526d6e5  f97c209b  7303295709       3
# 1   eb2d7e58  50d4e3b2  7308050880       1
# 2   faffd8ef  f97c209b  7313086119       2
# 3   4e3263fd  6eb4d8fb  7311883855       5
# 4   82f24729  b1b071b2  7313273600       3
# 5   6456f5de  50d4e3b2  7303734519       3
# 6   87a07c89  346050b0  7303236346       2
# 7   99c9003b  f97c209b  7311883855       2
# 8   0a2a1d76  25d1cb2b  7308683920       3
# 9   b7069b4a  32b272f2  7313086119       4
# 10  0d4d5bfa  32b272f2  7313273600       2
# 11  e46b3793  6eb4d8fb  7308268142       2
# 12  66d36428  32b272f2  7313340076       4
# 13  e2dc2954  90104220  7315807724       3
# 14  2a15188f  25d1cb2b  7316671476       3
#
#                                              comments
# 0   Very reliable and fuel-efficient. Your recent ...
# 1   The car's exterior design is sporty and eye-ca...
# 2   The car's infotainment system is intuitive and...
# 3   I had a great buying experience and the car is...
# 4   The adaptive cruise control works well. Chair ...
# 5   The car's headlights illuminate the road ahead...
# 6   The car's acceleration is brisk and powerful. ...
# 7   The car's technology enhances the driving expe...
# 8   The car's visibility is excellent from all ang...
# 9   The rearview camera provides a clear view. Fac...
# 10  The car's fuel efficiency is excellent. Part w...
# 11  The car's visibility is excellent from the dri...
# 12  The car's suspension offers a smooth and contr...
# 13  Acceleration is swift and powerful. Prove prob...
# 14  The car's steering wheel feels solid and well-...

# %%
num_rentals = 20

rental_data = {
    'rental_id': [str(uuid.uuid4())[:8] for _ in range(num_rentals)],
    'listing_id': np.random.choice(sample_listings_table['listing_id'], size=num_rentals),
    'user_id': np.random.choice(sample_users_table['user_id'], size=num_rentals),
    'rent_date': [datetime.now() - timedelta(days=random.randint(1, 365)) for _ in range(num_rentals)],
    'return_date': [None] * num_rentals,
    'status': ['renting'] * num_rentals
}

# Process each rental
for i in range(num_rentals):
    rent_date = rental_data['rent_date'][i]
    # Generate return date between 1 and 50 days after rent date
    return_date = rent_date + timedelta(days=random.randint(1, 50))
    # Check if the return date is in the past
    if return_date <= datetime.now():
        rental_data['return_date'][i] = return_date.strftime('%Y-%m-%d %H:%M')
        rental_data['status'][i] = 'returned'
    else:
        rental_data['return_date'][i] = None

sample_rentals_table = pd.DataFrame(rental_data)

sample_rentals_table['rent_date'] = sample_rentals_table['rent_date'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M'))
sample_rentals_table
# Out:
#    rental_id  listing_id   user_id         rent_date       return_date  \
# 0   ef8a1621  7313273600  90104220  2023-12-21 21:06  2023-12-23 21:06
# 1   bc0dacb4  7314618037  25d1cb2b  2023-07-07 21:06  2023-07-20 21:06
# 2   55f52ae1  7315807724  b1b071b2  2023-11-06 21:06  2023-12-24 21:06
# 3   c39c3dab  7312960878  32b272f2  2024-06-19 21:06              None
# 4   94c987e4  7313086119  6eb4d8fb  2024-06-01 21:06              None
# 5   4dfbe603  7303236346  76397991  2024-01-18 21:06  2024-02-10 21:06
# 6   1835e559  7311883855  b1b071b2  2024-01-17 21:06  2024-03-05 21:06
# 7   56420ecb  7314936270  32b272f2  2024-02-23 21:06  2024-03-05 21:06
# 8   dba672d8  7313394387  f97c209b  2024-02-25 21:06  2024-03-17 21:06
# 9   828bd5d8  7310842213  f97c209b  2024-06-01 21:06              None
# 10  969f7877  7314618037  04bc9af6  2024-01-31 21:06  2024-03-03 21:06
# 11  c76b1b76  7316764465  25d1cb2b  2023-08-08 21:06  2023-09-01 21:06
# 12  7c52a559  7316671476  04bc9af6  2024-01-15 21:06  2024-01-25 21:06
# 13  29864cf2  7315807724  25d1cb2b  2023-07-16 21:06  2023-08-06 21:06
# 14  25e3897b  7314936270  04bc9af6  2024-02-21 21:06  2024-03-17 21:06
# 15  ca627361  7313394387  50d4e3b2  2023-10-08 21:06  2023-10-31 21:06
# 16  1d40ea38  7310842213  50d4e3b2  2023-07-13 21:06  2023-08-25 21:06
# 17  48dd19d7  7303295709  32b272f2  2024-06-15 21:06              None
# 18  405edc29  7303734519  04bc9af6  2024-06-02 21:06              None
# 19  92d20984  7316671476  b1b071b2  2023-10-02 21:06  2023-10-05 21:06
#
#       status
# 0   returned
# 1   returned
# 2   returned
# 3    renting
# 4    renting
# 5   returned
# 6   returned
# 7   returned
# 8   returned
# 9    renting
# 10  returned
# 11  returned
# 12  returned
# 13  returned
# 14  returned
# 15  returned
# 16  returned
# 17   renting
# 18   renting
# 19  returned

# %%
state_data = {
    'state_id': ['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
                   'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'ma',
                   'mi', 'mn', 'ms', 'mo', 'mt', 'nc', 'ne', 'nv', 'nj', 'nm', 'ny',
                   'nh', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
                   'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'],
    'state_name': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'District of Columbia', 
                   'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 
                   'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 
                   'Montana', 'North Carolina', 'Nebraska', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'New Hampshire', 
                   'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 
                   'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
    'time_zone': ['Central', 'Alaska', 'Mountain', 'Central', 'Pacific', 'Mountain', 'Eastern', 'Eastern', 'Eastern', 'Eastern', 
                  'Eastern', 'Hawaii-Aleutian', 'Mountain', 'Central', 'Eastern', 'Central', 'Central', 'Eastern', 'Central', 
                  'Eastern', 'Eastern', 'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Central', 
                  'Pacific', 'Eastern', 'Mountain', 'Eastern', 'Eastern', 'Central', 'Eastern', 'Central', 'Pacific', 'Eastern', 
                  'Eastern', 'Eastern', 'Central', 'Central', 'Central', 'Mountain', 'Eastern', 'Eastern', 'Pacific', 'Eastern', 
                  'Central', 'Mountain']
}

sample_states_table = pd.DataFrame(state_data)
sample_states_table
# Out:
#    state_id            state_name        time_zone
# 0        al               Alabama          Central
# 1        ak                Alaska           Alaska
# 2        az               Arizona         Mountain
# 3        ar              Arkansas          Central
# 4        ca            California          Pacific
# 5        co              Colorado         Mountain
# 6        ct           Connecticut          Eastern
# 7        dc  District of Columbia          Eastern
# 8        de              Delaware          Eastern
# 9        fl               Florida          Eastern
# 10       ga               Georgia          Eastern
# 11       hi                Hawaii  Hawaii-Aleutian
# 12       id                 Idaho         Mountain
# 13       il              Illinois          Central
# 14       in               Indiana          Eastern
# 15       ia                  Iowa          Central
# 16       ks                Kansas          Central
# 17       ky              Kentucky          Eastern
# 18       la             Louisiana          Central
# 19       me                 Maine          Eastern
# 20       md              Maryland          Eastern
# 21       ma         Massachusetts          Eastern
# 22       mi              Michigan          Eastern
# 23       mn             Minnesota          Central
# 24       ms           Mississippi          Central
# 25       mo              Missouri          Central
# 26       mt               Montana         Mountain
# 27       nc        North Carolina          Eastern
# 28       ne              Nebraska          Central
# 29       nv                Nevada          Pacific
# 30       nj            New Jersey          Eastern
# 31       nm            New Mexico         Mountain
# 32       ny              New York          Eastern
# 33       nh         New Hampshire          Eastern
# 34       nd          North Dakota          Central
# 35       oh                  Ohio          Eastern
# 36       ok              Oklahoma          Central
# 37       or                Oregon          Pacific
# 38       pa          Pennsylvania          Eastern
# 39       ri          Rhode Island          Eastern
# 40       sc        South Carolina          Eastern
# 41       sd          South Dakota          Central
# 42       tn             Tennessee          Central
# 43       tx                 Texas          Central
# 44       ut                  Utah         Mountain
# 45       vt               Vermont          Eastern
# 46       va              Virginia          Eastern
# 47       wa            Washington          Pacific
# 48       wv         West Virginia          Eastern
# 49       wi             Wisconsin          Central
# 50       wy               Wyoming         Mountain

# %%
num_favorites = 20
favorite_data = {
    'id': [random.choice(sample_listings_table['listing_id']) for _ in range(num_favorites)],
    'user_id': [random.choice(sample_users_table['user_id']) for _ in range(num_favorites)]
}

sample_favorites_table = pd.DataFrame(favorite_data)

sample_favorites_table
# Out:
#             id   user_id
# 0   7313273600  25d1cb2b
# 1   7308268142  90104220
# 2   7308268142  6eb4d8fb
# 3   7316951646  76397991
# 4   7311883855  25d1cb2b
# 5   7313273600  04bc9af6
# 6   7313394387  6eb4d8fb
# 7   7308683920  90104220
# 8   7312960878  f97c209b
# 9   7313086119  25d1cb2b
# 10  7316671476  6eb4d8fb
# 11  7313086119  f97c209b
# 12  7311550702  6eb4d8fb
# 13  7312960878  50d4e3b2
# 14  7311550702  04bc9af6
# 15  7314936270  90104220
# 16  7314618037  04bc9af6
# 17  7303295709  f97c209b
# 18  7313086119  b1b071b2
# 19  7311550702  b1b071b2

# %%
# save da files
sample_cars_table.to_csv('sample_cars_table.csv', index=False)
sample_users_table.to_csv('sample_users_table.csv', index=False)
sample_owners_table.to_csv('sample_owners_table.csv', index=False)
sample_rentals_table.to_csv('sample_rentals_table.csv', index=False)
sample_listings_table.to_csv('sample_listings_table.csv', index=False)
sample_favorites_table.to_csv('sample_favorites_table.csv', index=False)
sample_states_table.to_csv('sample_states_table.csv', index=False)
sample_reviews_table.to_csv('sample_reviews_table.csv', index=False)

# %% [markdown]
# ### Data Summaries

# %%
lengths = []
for i in (df["url"] + df["image_url"]):
    lengths.append(len(str(i)))

max(lengths)
# Out:
# 169

# %%
# lat and long
max_lat = max(df["lat"].unique())
min_lat = min(df["lat"].unique())

max_long = max(df["long"].unique())
min_long = min(df["long"].unique())

print("lat: [", min_lat, ",", max_lat, "] long: [", min_long, ",", max_long, "]")
# Out:
# lat: [ -84.122245 , 82.390818 ] long: [ -159.827728 , 173.885502 ]

# %%
df["state"].dropna().unique()
# Out:
# array(['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
#        'hi', 'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'md', 'ma',
#        'mi', 'mn', 'ms', 'mo', 'mt', 'nc', 'ne', 'nv', 'nj', 'nm', 'ny',
#        'nh', 'nd', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
#        'ut', 'vt', 'va', 'wa', 'wv', 'wi', 'wy'], dtype=object)

# %%
df["condition"].dropna().unique()
# Out:
# array(['good', 'excellent', 'fair', 'like new', 'new', 'salvage'],
#       dtype=object)

# %%
user_favorites = favorites_table[favorites_table['userID'] == 'user_25764002']
user_favorites
# Out:
#                                favoriteID          id         userID
# 2    ee48c532-74cb-441b-866e-bc80d93b2983  7305679700  user_25764002
# 62   8bc0a3ef-2b21-4166-a4f3-3c71340284a1  7315916207  user_25764002
# 432  70b71a2d-2668-4515-858b-43cb648357db  7316856596  user_25764002
# 519  f1b6b231-3410-4140-aad3-2087e9e2f1a9  7313105260  user_25764002

# %%
len(df['manufacturer'].unique())
# Out:
# 42

# %%
df['model'].unique()
# Out:
# array(['sierra 1500 crew cab slt', 'silverado 1500',
#        'silverado 1500 crew', ..., 'gand wagoneer', '96 Suburban',
#        'Paige Glenbrook Touring'], dtype=object)

# %%
len(df['model'].unique())
# Out:
# 29667
